# %% [markdown]
# # ETL-Project-Stadiums

# %% [markdown]
# # Extract

# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# URL of page to be scraped
url = 'https://en.wikipedia.org/wiki/List_of_current_National_Football_League_stadiums'

tables = pd.read_html(url)
tables
# Out:
# [                                          0
#  0        Denotes stadium with a fixed roof.
#  1  Denotes stadium with a retractable roof.,
#      Image                        Name  Capacity                     Location  \
#  0     NaN           Allegiant Stadium     65000             Paradise, Nevada
#  1     NaN           Arrowhead Stadium     76416        Kansas City, Missouri
#  2     NaN                AT&T Stadium     80000             Arlington, Texas
#  3     NaN     Bank of America Stadium     75523    Charlotte, North Carolina
#  4     NaN           CenturyLink Field     69000          Seattle, Washington
#  5     NaN  Empower Field at Mile High     76125             Denver, Colorado
#  6     NaN                  FedExField     82000           Landover, Maryland
#  7     NaN         FirstEnergy Stadium     67895              Cleveland, Ohio
#  8     NaN                  Ford Field     65000            Detroit, Michigan
#  9     NaN            Gillette Stadium     66829    Foxborough, Massachusetts
#  10    NaN           Hard Rock Stadium     65326       Miami Gardens, Florida
#  11    NaN                 Heinz Field     68400     Pittsburgh, Pennsylvania
#  12    NaN               Lambeau Field     81441         Green Bay, Wisconsin
#  13    NaN              Levi's Stadium     68500      Santa Clara, California
#  14    NaN     Lincoln Financial Field     69596   Philadelphia, Pennsylvania
#  15    NaN           Lucas Oil Stadium     67000        Indianapolis, Indiana
#  16    NaN            M&T Bank Stadium     71008          Baltimore, Maryland
#  17    NaN     Mercedes-Benz Superdome     73208       New Orleans, Louisiana
#  18    NaN       Mercedes-Benz Stadium     71000             Atlanta, Georgia
#  19    NaN             MetLife Stadium     82500  East Rutherford, New Jersey
#  20    NaN               New Era Field     71608       Orchard Park, New York
#  21    NaN              Nissan Stadium     69143         Nashville, Tennessee
#  22    NaN                 NRG Stadium     72220               Houston, Texas
#  23    NaN          Paul Brown Stadium     65515             Cincinnati, Ohio
#  24    NaN       Raymond James Stadium     65890               Tampa, Florida
#  25    NaN                SoFi Stadium     70240        Inglewood, California
#  26    NaN               Soldier Field     61500            Chicago, Illinois
#  27    NaN          State Farm Stadium     63400            Glendale, Arizona
#  28    NaN             TIAA Bank Field     69132        Jacksonville, Florida
#  29    NaN           U.S. Bank Stadium     66655       Minneapolis, Minnesota
#
#                                              Surface    Roof type  \
#  0                                             Grass        Fixed
#  1                                     Bermuda grass         Open
#  2                                Hellas Matrix Turf  Retractable
#  3                                     Bermuda grass         Open
#  4                       FieldTurf Revolution 360[8]         Open
#  5                                Kentucky bluegrass         Open
#  6                                     Bermuda grass         Open
#  7                                Kentucky bluegrass         Open
#  8                           FieldTurf Classic HD[8]        Fixed
#  9                                 FieldTurf CORE[8]         Open
#  10                             Platinum TE Paspalum         Open
#  11                               Kentucky bluegrass         Open
#  12                            Desso GrassMaster[18]         Open
#  13       Bermuda grass / Perennial Ryegrass mixture         Open
#  14                            Desso GrassMaster[21]         Open
#  15                         Shaw Sports Momentum Pro  Retractable
#  16                                    Bermuda grass         Open
#  17                      FieldTurf Revolution 360[8]        Fixed
#  18                         FieldTurf Revolution[26]  Retractable
#  19  UBU Sports Speed Series S5-M Synthetic Turf[28]         Open
#  20                              A-Turf Titan 50[30]         Open
#  21                                    Bermuda grass         Open
#  22                           Hellas Matrix Turf[32]  Retractable
#  23             UBU Speed Series S5-M Synthetic Turf         Open
#  24                                    Bermuda grass         Open
#  25                                  Artificial turf        Fixed
#  26                               Kentucky bluegrass         Open
#  27                                    Bermuda grass  Retractable
#  28                                    Bermuda grass         Open
#  29         UBU Speed Series S5-M Synthetic Turf[40]        Fixed
#
#                                   Team(s)      Opened    Ref(s)
#  0                      Las Vegas Raiders        2020       [3]
#  1                     Kansas City Chiefs        1972       [4]
#  2                         Dallas Cowboys        2009    [5][6]
#  3                      Carolina Panthers        1996       [7]
#  4                       Seattle Seahawks        2002       [9]
#  5                         Denver Broncos        2001      [10]
#  6                    Washington Redskins        1997      [11]
#  7                       Cleveland Browns        1999  [12][13]
#  8                          Detroit Lions        2002      [14]
#  9                   New England Patriots        2002      [15]
#  10                        Miami Dolphins        1987      [16]
#  11                   Pittsburgh Steelers        2001      [17]
#  12                     Green Bay Packers        1957      [19]
#  13                   San Francisco 49ers        2014      [20]
#  14                   Philadelphia Eagles        2003      [22]
#  15                    Indianapolis Colts        2008      [23]
#  16                      Baltimore Ravens        1998      [24]
#  17                    New Orleans Saints        1975      [25]
#  18                       Atlanta Falcons        2017      [27]
#  19          New York GiantsNew York Jets        2010      [29]
#  20                         Buffalo Bills        1973      [30]
#  21                      Tennessee Titans        1999      [31]
#  22                        Houston Texans        2002      [33]
#  23                    Cincinnati Bengals        2000      [34]
#  24                  Tampa Bay Buccaneers        1998      [35]
#  25  Los Angeles RamsLos Angeles Chargers        2020      [36]
#  26                         Chicago Bears  1924[nb 1]      [37]
#  27                     Arizona Cardinals        2006      [38]
#  28                  Jacksonville Jaguars        1995      [39]
#  29                     Minnesota Vikings        2016      [41]  ,
#     Image                          Stadium      Capacity             Location  \
#  0    NaN            Camping World Stadium         65000     Orlando, Florida
#  1    NaN                   Estadio Azteca    87,523[42]  Mexico City, Mexico
#  2    NaN  Tom Benson Hall of Fame Stadium         22364         Canton, Ohio
#  3    NaN                  Wembley Stadium  86,000[nb 4]      London, England
#  4    NaN        Tottenham Hotspur Stadium         62062      London, England
#
#                        Surface              Roof type           Event(s)  \
#  0  AstroTurf GameDay Grass 3D                   Open           Pro Bowl
#  1                       Grass                   Open    NFL Mexico Game
#  2        FieldTurf Classic HD                   Open  Hall of Fame Game
#  3           Desso GrassMaster  Partially retractable   NFL London Games
#  4             Artificial turf                   Open   NFL London Games
#
#         Opened Ref(s)
#  0  1936[nb 2]    NaN
#  1        1966    NaN
#  2  1938[nb 3]   [43]
#  3        2007    NaN
#  4        2019   [44]  ,
#              Stadium  Capacity           Location Surface Roof type  \
#  0  New Era Field II       NaN  Buffalo, New York   Grass      Open
#  1  Redskins Stadium   60000.0                NaN     NaN      Open
#
#                 Team(s)  Opening  Ref(s)
#  0        Buffalo Bills      NaN     NaN
#  1  Washington Redskins      NaN     NaN  ,
#     vteCurrent stadiums of the National Football League  \
#  0                                                 AFC
#  1   EastNorthSouthWest Gillette Stadium Hard Rock ...
#  2                                                East
#  3   Gillette Stadium Hard Rock Stadium MetLife Sta...
#  4                                                 NFC
#  5   EastNorthSouthWest AT&T Stadium FedExField Lin...
#  6                                                East
#  7   AT&T Stadium FedExField Lincoln Financial Fiel...
#  8   Hall of Fame Game Tom Benson Hall of Fame Stad...
#  9                                   Hall of Fame Game
#  10                                           Pro Bowl
#  11                               International Series
#  12  1 Both the New York Giants (NFC) and the New Y...
#
#     vteCurrent stadiums of the National Football League.1  \
#  0   EastNorthSouthWest Gillette Stadium Hard Rock ...
#  1   EastNorthSouthWest Gillette Stadium Hard Rock ...
#  2                                               North
#  3   FirstEnergy Stadium Heinz Field M&T Bank Stadi...
#  4   EastNorthSouthWest AT&T Stadium FedExField Lin...
#  5   EastNorthSouthWest AT&T Stadium FedExField Lin...
#  6                                               North
#  7   Ford Field Lambeau Field Soldier Field U.S. Ba...
#  8   Hall of Fame Game Tom Benson Hall of Fame Stad...
#  9                     Tom Benson Hall of Fame Stadium
#  10                              Camping World Stadium
#  11  Wembley Stadium Tottenham Hotspur Stadium Esta...
#  12  1 Both the New York Giants (NFC) and the New Y...
#
#                                             Unnamed: 2  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                               South
#  3   Lucas Oil Stadium Nissan Stadium NRG Stadium T...
#  4                                                 NaN
#  5                                                 NaN
#  6                                               South
#  7   Bank of America Stadium Mercedes-Benz Stadium ...
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#
#                                             Unnamed: 3
#  0                                                 NaN
#  1                                                 NaN
#  2                                                West
#  3   Allegiant Stadium Arrowhead Stadium Empower Fi...
#  4                                                 NaN
#  5                                                 NaN
#  6                                                West
#  7   CenturyLink Field Levi's Stadium SoFi Stadium2...
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN  ,
#                                                     0  \
#  0  EastNorthSouthWest Gillette Stadium Hard Rock ...
#  1                                               East
#  2  Gillette Stadium Hard Rock Stadium MetLife Sta...
#
#                                                     1  \
#  0  EastNorthSouthWest Gillette Stadium Hard Rock ...
#  1                                              North
#  2  FirstEnergy Stadium Heinz Field M&T Bank Stadi...
#
#                                                     2  \
#  0                                                NaN
#  1                                              South
#  2  Lucas Oil Stadium Nissan Stadium NRG Stadium T...
#
#                                                     3
#  0                                                NaN
#  1                                               West
#  2  Allegiant Stadium Arrowhead Stadium Empower Fi...  ,
#                                                     0  \
#  0                                               East
#  1  Gillette Stadium Hard Rock Stadium MetLife Sta...
#
#                                                     1  \
#  0                                              North
#  1  FirstEnergy Stadium Heinz Field M&T Bank Stadi...
#
#                                                     2  \
#  0                                              South
#  1  Lucas Oil Stadium Nissan Stadium NRG Stadium T...
#
#                                                     3
#  0                                               West
#  1  Allegiant Stadium Arrowhead Stadium Empower Fi...  ,
#                                                     0  \
#  0  EastNorthSouthWest AT&T Stadium FedExField Lin...
#  1                                               East
#  2  AT&T Stadium FedExField Lincoln Financial Fiel...
#
#                                                     1  \
#  0  EastNorthSouthWest AT&T Stadium FedExField Lin...
#  1                                              North
#  2  Ford Field Lambeau Field Soldier Field U.S. Ba...
#
#                                                     2  \
#  0                                                NaN
#  1                                              South
#  2  Bank of America Stadium Mercedes-Benz Stadium ...
#
#                                                     3
#  0                                                NaN
#  1                                               West
#  2  CenturyLink Field Levi's Stadium SoFi Stadium2...  ,
#                                                     0  \
#  0                                               East
#  1  AT&T Stadium FedExField Lincoln Financial Fiel...
#
#                                                     1  \
#  0                                              North
#  1  Ford Field Lambeau Field Soldier Field U.S. Ba...
#
#                                                     2  \
#  0                                              South
#  1  Bank of America Stadium Mercedes-Benz Stadium ...
#
#                                                     3
#  0                                               West
#  1  CenturyLink Field Levi's Stadium SoFi Stadium2...  ,
#                        0                                                  1
#  0     Hall of Fame Game                    Tom Benson Hall of Fame Stadium
#  1              Pro Bowl                              Camping World Stadium
#  2  International Series  Wembley Stadium Tottenham Hotspur Stadium Esta...,
#                     vteNational Football League (2020)  \
#  0                                                 AFC
#  1   EastNorthSouthWest Buffalo Bills Miami Dolphin...
#  2                                                East
#  3   Buffalo Bills Miami Dolphins New England Patri...
#  4                                                 NFC
#  5   EastNorthSouthWest Dallas Cowboys New York Gia...
#  6                                                East
#  7   Dallas Cowboys New York Giants Philadelphia Ea...
#  8   Seasons Seasons by team Preseason Hall of Fame...
#  9                                             Seasons
#  10                                            History
#  11                                           Business
#  12                                              Other
#
#                   vteNational Football League (2020).1  \
#  0   EastNorthSouthWest Buffalo Bills Miami Dolphin...
#  1   EastNorthSouthWest Buffalo Bills Miami Dolphin...
#  2                                               North
#  3   Baltimore Ravens Cincinnati Bengals Cleveland ...
#  4   EastNorthSouthWest Dallas Cowboys New York Gia...
#  5   EastNorthSouthWest Dallas Cowboys New York Gia...
#  6                                               North
#  7   Chicago Bears Detroit Lions Green Bay Packers ...
#  8   Seasons Seasons by team Preseason Hall of Fame...
#  9   Seasons by team Preseason Hall of Fame Game Am...
#  10  League history Executive history Championship ...
#  11  Owners Properties Management Council Competiti...
#  12  Officials Stadiums Chronology Awards All-Pro H...
#
#                                             Unnamed: 2  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                               South
#  3   Houston Texans Indianapolis Colts Jacksonville...
#  4                                                 NaN
#  5                                                 NaN
#  6                                               South
#  7   Atlanta Falcons Carolina Panthers New Orleans ...
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#
#                                             Unnamed: 3
#  0                                                 NaN
#  1                                                 NaN
#  2                                                West
#  3   Denver Broncos Kansas City Chiefs Las Vegas Ra...
#  4                                                 NaN
#  5                                                 NaN
#  6                                                West
#  7   Arizona Cardinals Los Angeles Rams San Francis...
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN  ,
#                                                     0  \
#  0  EastNorthSouthWest Buffalo Bills Miami Dolphin...
#  1                                               East
#  2  Buffalo Bills Miami Dolphins New England Patri...
#
#                                                     1  \
#  0  EastNorthSouthWest Buffalo Bills Miami Dolphin...
#  1                                              North
#  2  Baltimore Ravens Cincinnati Bengals Cleveland ...
#
#                                                     2  \
#  0                                                NaN
#  1                                              South
#  2  Houston Texans Indianapolis Colts Jacksonville...
#
#                                                     3
#  0                                                NaN
#  1                                               West
#  2  Denver Broncos Kansas City Chiefs Las Vegas Ra...  ,
#                                                     0  \
#  0                                               East
#  1  Buffalo Bills Miami Dolphins New England Patri...
#
#                                                     1  \
#  0                                              North
#  1  Baltimore Ravens Cincinnati Bengals Cleveland ...
#
#                                                     2  \
#  0                                              South
#  1  Houston Texans Indianapolis Colts Jacksonville...
#
#                                                     3
#  0                                               West
#  1  Denver Broncos Kansas City Chiefs Las Vegas Ra...  ,
#                                                     0  \
#  0  EastNorthSouthWest Dallas Cowboys New York Gia...
#  1                                               East
#  2  Dallas Cowboys New York Giants Philadelphia Ea...
#
#                                                     1  \
#  0  EastNorthSouthWest Dallas Cowboys New York Gia...
#  1                                              North
#  2  Chicago Bears Detroit Lions Green Bay Packers ...
#
#                                                     2  \
#  0                                                NaN
#  1                                              South
#  2  Atlanta Falcons Carolina Panthers New Orleans ...
#
#                                                     3
#  0                                                NaN
#  1                                               West
#  2  Arizona Cardinals Los Angeles Rams San Francis...  ,
#                                                     0  \
#  0                                               East
#  1  Dallas Cowboys New York Giants Philadelphia Ea...
#
#                                                     1  \
#  0                                              North
#  1  Chicago Bears Detroit Lions Green Bay Packers ...
#
#                                                     2  \
#  0                                              South
#  1  Atlanta Falcons Carolina Panthers New Orleans ...
#
#                                                     3
#  0                                               West
#  1  Arizona Cardinals Los Angeles Rams San Francis...  ,
#            0                                                  1
#  0   Seasons  Seasons by team Preseason Hall of Fame Game Am...
#  1   History  League history Executive history Championship ...
#  2  Business  Owners Properties Management Council Competiti...
#  3     Other  Officials Stadiums Chronology Awards All-Pro H...]

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 16

# %%
tables[1].head()
# Out:
#    Image                     Name  Capacity                   Location  \
# 0    NaN        Allegiant Stadium     65000           Paradise, Nevada
# 1    NaN        Arrowhead Stadium     76416      Kansas City, Missouri
# 2    NaN             AT&T Stadium     80000           Arlington, Texas
# 3    NaN  Bank of America Stadium     75523  Charlotte, North Carolina
# 4    NaN        CenturyLink Field     69000        Seattle, Washington
#
#                        Surface    Roof type             Team(s) Opened  Ref(s)
# 0                        Grass        Fixed   Las Vegas Raiders   2020     [3]
# 1                Bermuda grass         Open  Kansas City Chiefs   1972     [4]
# 2           Hellas Matrix Turf  Retractable      Dallas Cowboys   2009  [5][6]
# 3                Bermuda grass         Open   Carolina Panthers   1996     [7]
# 4  FieldTurf Revolution 360[8]         Open    Seattle Seahawks   2002     [9]

# %% [markdown]
# # Transform

# %%
df=tables[1]

# %%
# new data frame with split value columns 
new = df["Location"].str.split(",", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["City"]= new[0] 
  
# making separate last name column from new data frame 
df["State"]= new[1]

# %%
df.head()
# Out:
#    Image                     Name  Capacity                   Location  \
# 0    NaN        Allegiant Stadium     65000           Paradise, Nevada
# 1    NaN        Arrowhead Stadium     76416      Kansas City, Missouri
# 2    NaN             AT&T Stadium     80000           Arlington, Texas
# 3    NaN  Bank of America Stadium     75523  Charlotte, North Carolina
# 4    NaN        CenturyLink Field     69000        Seattle, Washington
#
#                        Surface    Roof type             Team(s) Opened  \
# 0                        Grass        Fixed   Las Vegas Raiders   2020
# 1                Bermuda grass         Open  Kansas City Chiefs   1972
# 2           Hellas Matrix Turf  Retractable      Dallas Cowboys   2009
# 3                Bermuda grass         Open   Carolina Panthers   1996
# 4  FieldTurf Revolution 360[8]         Open    Seattle Seahawks   2002
#
#    Ref(s)         City            State
# 0     [3]     Paradise           Nevada
# 1     [4]  Kansas City         Missouri
# 2  [5][6]    Arlington            Texas
# 3     [7]    Charlotte   North Carolina
# 4     [9]      Seattle       Washington

# %%
df['Teams']=df['Team(s)']
stadiums=df[['Name', 'Capacity','City', 'State','Surface','Roof type','Teams', 'Opened']]
stadiums.head()
# Out:
#                       Name  Capacity         City            State  \
# 0        Allegiant Stadium     65000     Paradise           Nevada
# 1        Arrowhead Stadium     76416  Kansas City         Missouri
# 2             AT&T Stadium     80000    Arlington            Texas
# 3  Bank of America Stadium     75523    Charlotte   North Carolina
# 4        CenturyLink Field     69000      Seattle       Washington
#
#                        Surface    Roof type               Teams Opened
# 0                        Grass        Fixed   Las Vegas Raiders   2020
# 1                Bermuda grass         Open  Kansas City Chiefs   1972
# 2           Hellas Matrix Turf  Retractable      Dallas Cowboys   2009
# 3                Bermuda grass         Open   Carolina Panthers   1996
# 4  FieldTurf Revolution 360[8]         Open    Seattle Seahawks   2002

# %%
stadiums.dtypes
# Out:
# Name         object
# Capacity      int64
# City         object
# State        object
# Surface      object
# Roof type    object
# Team(s)      object
# Opened       object
# dtype: object

# %% [markdown]
# # Load

# %%
#Import additional dependancies
from sqlalchemy import create_engine
from sqlalchemy.types import Integer,BigInteger
import psycopg2

# %%
#Session Engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/nfl_db')
connection = engine.connect()

# %%
# #Establishing the connection
# conn = psycopg2.connect(
#    database="nfl_db", user='postgres', password='postgres', host='127.0.0.1', port= '5432'
# )
# #Creating a cursor object using the cursor() method
# cursor = conn.cursor()

# #Doping EMPLOYEE table if already exists.
# cursor.execute("DROP TABLE IF EXISTS salary")

# #Creating table as per requirement
# sql ='''CREATE TABLE salary(
#    Rank INT NOT NULL,
#    First_Name CHAR(30) NOT NULL,
#    Last_Name CHAR(30)NOT NULL,
#    POS CHAR(2) NOT NULL,
#    TM CHAR(3) NOT NULL,
#    Salary INT NOT NULL,
#    Primary Key (Rank)
# )'''
# cursor.execute(sql)
# print("Table created successfully........")

# #Closing the connection
# conn.close()

# %%
#Load dataframe to PostgreSQL
stadiums.to_sql('stadiums', engine,
               dtype={"Capacity": Integer()},
                      index=False)
