# %%
import pandas as pd

# %%
defense= pd.read_csv("roster/defense.csv")
offense= pd.read_csv("roster/offense.csv")
special= pd.read_csv("roster/special.csv")

# %%
players_df = pd.concat([defense,offense])
players_df = pd.concat([players_df,special])
players_df = players_df.drop(columns=['Unnamed: 0']).reset_index(drop=True)

# %%
import re 
  
def remove(list): 
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list] 
    return list
players_df["FullName"]=remove(players_df.Name)

# %%
first = []
last = []

test = [name.split for name in players_df.FullName]
for name in players_df.FullName:
    name_split = name.split(' ')
    if len(name_split)<3:
        
        first.append(name_split[0])
        last.append(name_split[1])
    else:
        first.append(name_split[0])
        last.append(name_split[1]+" " +name_split[2])

players_df["First Name"] = first
players_df["Last Name"] = last

# %%
team_abv_list = []
for i in range(0,len(players_df.team)):
    x = True
    for j in range(0,len(team_df.Team)):
        
        if players_df.team[i] in team_df.Team[j] and x == True:
                   
            team_abv_list.append(team_df.TM[j])
            x=False
                   
            
            
players_df['TeamID']=team_abv_list

# %%
players_df.to_csv("temp/players_df.csv")

# %%
metrics
# Out:
#                   Name  Height   Weight Forty Yard Dash Shuttle Time  \
# 0            Tom Brady   6' 4"  225 lbs        5.28 sec     4.38 sec
# 1           Drew Brees   6' 0"  209 lbs        4.83 sec     4.21 sec
# 2           Will Allen  5' 10"  192 lbs        4.58 sec     4.25 sec
# 3         Reggie Wayne   6' 0"  203 lbs        4.45 sec          NaN
# 4          Steve Smith   5' 9"  195 lbs        4.44 sec     4.19 sec
# ...                ...     ...      ...             ...          ...
# 3646       Evan Weaver   6' 2"  237 lbs        4.76 sec     4.21 sec
# 3647     Casey Toohill   6' 4"  250 lbs        4.62 sec     4.21 sec
# 3648      Mykal Walker   6' 3"  230 lbs        4.65 sec     4.25 sec
# 3649  Chapelle Russell   6' 2"  236 lbs        4.69 sec     4.41 sec
# 3650     Justin Strnad   6' 3"  238 lbs        4.74 sec     4.49 sec
#
#      Vertical Jump Broad Jump Bench Press Cone Drill
# 0          24.5 in      99 in         NaN   7.20 sec
# 1          32.0 in     105 in         NaN   7.09 sec
# 2          36.0 in     115 in         NaN   7.06 sec
# 3          36.0 in        NaN         NaN        NaN
# 4          38.0 in     120 in         NaN   6.68 sec
# ...            ...        ...         ...        ...
# 3646       32.0 in     117 in     15 reps   7.02 sec
# 3647       39.0 in     126 in     17 reps   7.08 sec
# 3648       33.0 in     122 in     20 reps   7.09 sec
# 3649       35.0 in     121 in     21 reps   7.38 sec
# 3650       29.0 in     113 in         NaN        NaN
#
# [3651 rows x 9 columns]

# %%
players_df.rename(columns={})
# Out:
#                    Name POS Age      HT       WT Exp             College  \
# 0       Mario Addison97  DE  32   6' 3"  260 lbs  10                Troy
# 1       Bryan Cox Jr.94  DE  25   6' 3"  270 lbs   4             Florida
# 2          AJ Epenesa57  DE  21   6' 6"  280 lbs   R                Iowa
# 3        Jerry Hughes55  DE  31   6' 2"  254 lbs  11                 TCU
# 4      Darryl Johnson92  DE  23   6' 6"  253 lbs   2  North Carolina A&T
# ...                 ...  ..  ..     ...      ...  ..                 ...
# 2835  Mitch Wishnowsky6   P  28   6' 2"  220 lbs   2                Utah
# 2836      Kyle Nelson86  LS  33   6' 2"  240 lbs   9    New Mexico State
# 2837       Jason Myers5  PK  28  5' 10"  190 lbs   6              Marist
# 2838   Michael Dickson4   P  24   6' 2"  208 lbs   3               Texas
# 2839        Tyler Ott69  LS  28   6' 3"  253 lbs   6             Harvard
#
#           team          FullName First Name   Last Name TeamID
# 0        Bills     Mario Addison      Mario     Addison    BUF
# 1        Bills     Bryan Cox Jr.      Bryan     Cox Jr.    BUF
# 2        Bills        AJ Epenesa         AJ     Epenesa    BUF
# 3        Bills      Jerry Hughes      Jerry      Hughes    BUF
# 4        Bills    Darryl Johnson     Darryl     Johnson    BUF
# ...        ...               ...        ...         ...    ...
# 2835     49ers  Mitch Wishnowsky      Mitch  Wishnowsky     SF
# 2836     49ers       Kyle Nelson       Kyle      Nelson     SF
# 2837  Seahawks       Jason Myers      Jason       Myers    SEA
# 2838  Seahawks   Michael Dickson    Michael     Dickson    SEA
# 2839  Seahawks         Tyler Ott      Tyler         Ott    SEA
#
# [2840 rows x 12 columns]

# %%
#Player Metrics

# %%
metric = pd.read_csv("rotowire/cleaned_rotowire2.csv")

# %%
metrics = metric[["Name", "Height", "Weight", "Forty Yard Dash", "Shuttle Time", "Vertical Jump", "Broad Jump", "Bench Press", "Cone Drill"]]
metrics

pd.merge(players_df, metrics, on='Name', how = 'right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-837e9f8dba18> in <module>
#       2 metrics
#       3
# ----> 4 pd.merge(player_df, metrics, on='Name', how = 'right')
#
# NameError: name 'player_df' is not defined

# %%
owners_df = pd.read_csv("temp/owners_df.csv")
salary_df = pd.read_csv("temp/salary_df.csv")
stadium_df = pd.read_csv("temp/stadium_df.csv")
team_df = pd.read_csv("temp/team_df.csv")
team_table = pd.read_csv("temp/team_table.csv")

# %%
team_df
# Out:
#      TM                  Team
# 0   ARI     Arizona Cardinals
# 1   ATL       Atlanta Falcons
# 2   BAL      Baltimore Ravens
# 3   BUF         Buffalo Bills
# 4   CAR     Carolina Panthers
# 5   CHI         Chicago Bears
# 6   CIN    Cincinnati Bengals
# 7   CLE      Cleveland Browns
# 8   DAL        Dallas Cowboys
# 9   DEN        Denver Broncos
# 10  DET         Detroit Lions
# 11   GB     Green Bay Packers
# 12  HOU        Houston Texans
# 13  IND    Indianapolis Colts
# 14  JAX  Jacksonville Jaguars
# 15   KC    Kansas City Chiefs
# 16  LAC  Los Angeles Chargers
# 17  LAR      Los Angeles Rams
# 18   LV     Las Vegas Raiders
# 19  MIA        Miami Dolphins
# 20  MIN     Minnesota Vikings
# 21   NE  New England Patriots
# 22   NO    New Orleans Saints
# 23  NYG       New York Giants
# 24  NYJ         New York Jets
# 25  PHI   Philadelphia Eagles
# 26  PIT   Pittsburgh Steelers
# 27  SEA      Seattle Seahawks
# 28   SF   San Francisco 49ers
# 29   TB  Tampa Bay Buccaneers
# 30  TEN      Tennessee Titans
# 31  WAS   Washington Redskins

# %%
team_df.head()
# Out:
#     TM               Team
# 0  ARI  Arizona Cardinals
# 1  ATL    Atlanta Falcons
# 2  BAL   Baltimore Ravens
# 3  BUF      Buffalo Bills
# 4  CAR  Carolina Panthers

# %%
players_df.to_csv("temp/players_df.csv")

# %%
team_abv_list = []
for i in range(0,len(players_df.team)):
    x = True
    for j in range(0,len(team_df.Team)):
        
        if players_df.team[i] in team_df.Team[j] and x == True:
                   
            team_abv_list.append(team_df.TM[j])
            x=False
                   
            
            
team_abv_list
# Out:
# ['BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'NYJ',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'BAL',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CIN',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'CLE',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'PIT',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'HOU',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'JAX',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'TEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'DEN',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'KC',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LV',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'LAC',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'DAL',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'NYG',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'PHI',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'WAS',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'CHI',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'DET',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'GB',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'MIN',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  'ATL',
#  ...]
