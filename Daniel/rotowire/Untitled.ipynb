# %%
import pandas as pd

# %%
df =pd.read_csv("cleaned_rotowire.csv")
df.shape
# Out:
# (3651, 22)

# %%
pd.read_csv("rotowire.csv")
# Out:
#        Unnamed: 0                   Name Height Height Percentile Weight  \
# 0               0             Dan Marino    NaN               NaN    NaN
# 1               1  Abdul-Karim Al-Jabbar    NaN               NaN    NaN
# 2               2             Joe Nedney    NaN               NaN    NaN
# 3               3          O.J. McDuffie    NaN               NaN    NaN
# 4               4           Chris Gedney    NaN               NaN    NaN
# ...           ...                    ...    ...               ...    ...
# 14157       14157            Cedric Byrd    NaN               NaN    NaN
# 14158       14158       Juwan Washington    NaN               NaN    NaN
# 14159       14159         Rashad Medaris    NaN               NaN    NaN
# 14160       14160           Romeo Finley    NaN               NaN    NaN
# 14161       14161            Juju Hughes    NaN               NaN    NaN
#
#       Weight Percentile Forty Yard Dash Forty Yard Dash Percentile  \
# ...
