# %%
# Dependencies
from bs4 import *
import requests
import re
import pandas as pd
#import time

# %%
# URL of page to be scraped
#url = 'https://www.rotowire.com/football/player.php?id=5000'

# %%
# Retrieve page with the requests module
#response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
#soup = BeautifulSoup(response.text, 'html.parser')

# %%
# name_list =[]
# birthday_list=[]
# college_list=[]
# player_id = []
# height_list=[]
# weight_list=[]
# forty_list = []
# shuttle_list = []
# cone_list = []
# vertical_list=[]
# broad_list=[]
# bench_list=[]
# hand_list=[]
# arm_list=[]

# height_list_p=[]
# weight_list_p=[]
# forty_list_p = []
# shuttle_list_p = []
# cone_list_p = []
# vertical_list_p=[]
# broad_list_p=[]
# bench_list_p=[]
# hand_list_p=[]
# arm_list_p=[]

#for i in range(1,10):
for i in range(1764,20000):
    url = f'https://www.rotowire.com/football/player.php?id={i}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    try:
        name = soup.find("div", class_="p-card__player-name").text
        name_list.append(name)
    except:
        continue
    player_id.append(i)
    try:
        birthday=soup.find_all("div", class_="p-card__meta-data-item")
        x=True
        for j in range(0,len(birthday)):
            if 'DOB' in birthday[j].text and x==True:
                birthday_list.append(birthday[j].text)
                x=False
            if j == len(birthday)-1 and x==True:
                birthday_list.append("NaN")        
    except:
        birthday_list.append("NaN")
        
    try:
        college=soup.find_all("div", class_="p-card__meta-data-item")
        x=True
        for j in range(0,len(college)):
            if 'College' in college[j].text and x==True:
                college_list.append(college[j].text)
                x=False
            if j == len(birthday)-1 and x==True:
                college_list.append("NaN")         
        
        
    except:
        college_list.append("NaN")
        
    try:
        height = soup.find("div", text="Height").find_parent("div").b.text
        height_percentile = soup.find("div", text="Height").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        height_list.append(height)
        height_list_p.append(height_percentile)
    except:
        height_list.append("NaN")
        height_list_p.append("NaN")
        
    try:
        weight = soup.find("div", text="Weight").find_parent("div").b.text
        weight_percentile = soup.find("div", text="Weight").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        weight_list.append(weight)
        weight_list_p.append(weight_percentile)
    except:
        weight_list.append("NaN")
        weight_list_p.append("NaN")
        
    try:
        forty = soup.find("div", text="40-Yard Dash").find_parent("div").b.text
        forty_percentile = soup.find("div", text="40-Yard Dash").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        forty_list.append(forty)
        forty_list_p.append(forty_percentile)
    except:
        forty_list.append("NaN")
        forty_list_p.append("NaN")
        
    try:
        shuttle = soup.find("div", text="Shuttle Time").find_parent("div").b.text
        shuttle_percentile = soup.find("div", text="Shuttle Time").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        shuttle_list.append(shuttle)
        shuttle_list_p.append(shuttle_percentile)
    except:
        shuttle_list.append("NaN")
        shuttle_list_p.append("NaN")
        
    try:
        cone = soup.find("div", text="Cone Drill").find_parent("div").b.text
        cone_percentile = soup.find("div", text="Cone Drill").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        cone_list.append(cone)
        cone_list_p.append(cone_percentile)
    except:
        cone_list.append("NaN")
        cone_list_p.append("NaN")
    
    try:
        vertical = soup.find("div", text="Vertical Jump").find_parent("div").b.text
        vertical_percentile = soup.find("div", text="Vertical Jump").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        vertical_list.append(vertical)
        vertical_list_p.append(vertical_percentile)
    except:
        vertical_list.append("NaN")
        vertical_list_p.append("NaN")
    
    try:
        broad = soup.find("div", text="Broad Jump").find_parent("div").b.text
        broad_percentile = soup.find("div", text="Broad Jump").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        broad_list.append(broad)
        broad_list_p.append(broad_percentile)
    except:
        broad_list.append("NaN")
        broad_list_p.append("NaN")
        
    try:
        bench = soup.find("div", text="Bench Press").find_parent("div").b.text
        bench_percentile = soup.find("div", text="Bench Press").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        bench_list.append(bench)
        bench_list_p.append(bench_percentile)
    except:
        bench_list.append("NaN")
        bench_list_p.append("NaN")
        
    try:
        hand = soup.find("div", text="Hand Length").find_parent("div").b.text
        hand_percentile = soup.find("div", text="Hand Length").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        hand_list.append(hand)
        hand_list_p.append(hand_percentile)
    except:
        hand_list.append("NaN")
        hand_list_p.append("NaN")
        
    try:
        arm = soup.find("div", text="Arm Length").find_parent("div").b.text
        arm_percentile = soup.find("div", text="Arm Length").find_parent("div").find_parent("div").findChildren("div", class_="meter__value")[0].get("style").split(":")[1].split(";")[0]
        arm_list.append(arm)
        arm_list_p.append(arm_percentile)
    except:
        arm_list.append("NaN")
        arm_list_p.append("NaN")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# OSError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# ProtocolError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-11-46ea08824635> in <module>
#      28 for i in range(1764,20000):
#      29     url = f'https://www.rotowire.com/football/player.php?id={i}'
# ---> 30     response = requests.get(url)
#      31     soup = BeautifulSoup(response.text, 'html.parser')
#      32
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')"))

# %%
#id-number made it to iteration: 16963
rotowire_df = pd.DataFrame({
    "Name":name_list,
    "PlayerID":player_id,
    "Height":height_list,
    "Height Percentile":height_list_p,
    "Weight":weight_list,
    "Weight Percentile":weight_list_p,
    "Forty Yard Dash":forty_list,
    "Forty Yard Dash Percentile":forty_list_p,
    "Shuttle Time": shuttle_list,
    "Shuttle TIme Percentile": shuttle_list_p,
    "Cone Drill":cone_list,
    "Cone Drill Percentile": cone_list_p,
    "Vertical Jump": vertical_list,
    "Vertical Jump Percentile":vertical_list_p,
    "Broad Jump": broad_list,
    "Broad Jump Percentile":broad_list_p,
    "Bench Press": bench_list,
    "Bench Press Percentile": bench_list_p,
    "Hand Length":hand_list,
    "Hand Length Percentil": hand_list_p,
    "Arm Length": arm_list,
    "Arm Length Percentile":arm_list_p
})
rotowire_df.to_csv("rotowire/rotowire.csv")

# %%
print(i)
# Out:
# 16017

# %%
cleaned_rotowire = rotowire_df[rotowire_df.Height != 'NaN']
cleaned_rotowire.to_csv("rotowire/cleaned_rotowire2.csv")

# %%
#There was an error in the code for:
#birthday_list
#college_list

print(len(player_id))
print(len(name_list))
print(len(birthday_list))
print(len(college_list))

print(len(height_list))
print(len(weight_list))
print(len(forty_list ))
print(len(shuttle_list ))
print(len(cone_list ))
print(len(vertical_list))
print(len(broad_list))
print(len(bench_list))
print(len(hand_list))
print(len(arm_list))

print(len(height_list_p))
print(len(weight_list_p))
print(len(forty_list_p) )
print(len(shuttle_list_p ))
print(len(cone_list_p ))
print(len(vertical_list_p))
print(len(broad_list_p))
print(len(bench_list_p))
print(len(hand_list_p))
print(len(arm_list_p))
# Out:
# 14174
# 14174
# 13924
# 13924
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
# 14174
