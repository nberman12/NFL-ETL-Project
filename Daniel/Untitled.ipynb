# %%
import pandas as pd

# %%
scoring_df = pd.read_csv("stats/scoring.csv")
returning_df= pd.read_csv("stats/returning.csv")

# %%
scoring_df.rename({
    "('Unnamed: 0_level_0', 'GP')":"GP",
    "('Touchdowns', 'RUSH')":"TD_RUSH",
    "('Touchdowns', 'REC')":"TD_REC",
    "('Touchdowns', 'RET')":"TD_RET",
    "('Touchdowns', 'TD')":"TD",
    "('Scoring', 'FG')":"SCORING_FG",
    "('Scoring', 'PAT')":"SCORING_PAT",
    "('Scoring', '2PT')":"SCORING_2PT",
    "('Scoring', 'PTS')":"SCORING_PTS",
    "('Scoring', 'TP/G')":"SCORING_TP/G"})
# Out:
#      Unnamed: 0                 Name  ('Unnamed: 0_level_0', 'GP')  \
# 0             0  Stephen Hauschka PK                            16
# 1             1        Josh Allen QB                            16
# 2             2      Cole Beasley WR                            15
# 3             3        John Brown WR                            15
# 4             4  Devin Singletary RB                            12
# ..          ...                  ...                           ...
# 473         473      Nick Bellore FB                            14
# 474         474      C.J. Prosise RB                             9
# 475         475      Quandre Diggs S                             5
# 476         476      Malik Turner WR                            15
# 477         477    Marshawn Lynch RB                             1
#
#      ('Touchdowns', 'RUSH')  ('Touchdowns', 'REC')  ('Touchdowns', 'RET')  \
# 0                         0                      0                      0
# 1                         9                      0                      0
# 2                         0                      6                      0
# 3                         0                      6                      0
# 4                         2                      2                      0
# ..                      ...                    ...                    ...
# 473                       0                      1                      0
# 474                       1                      0                      0
# 475                       0                      0                      1
# 476                       0                      1                      0
# 477                       1                      0                      0
#
#      ('Touchdowns', 'TD')  ('Scoring', 'FG')  ('Scoring', 'PAT')  \
# 0                       0                 22                  30
# 1                       9                  0                   0
# 2                       6                  0                   0
# 3                       6                  0                   0
# 4                       4                  0                   0
# ..                    ...                ...                 ...
# 473                     1                  0                   0
# 474                     1                  0                   0
# 475                     1                  0                   0
# 476                     1                  0                   0
# 477                     1                  0                   0
#
#      ('Scoring', '2PT')  ('Scoring', 'PTS')  ('Scoring', 'TP/G')    class  \
# 0                     0                  96                  6.0  Scoring
# 1                     1                  56                  3.5  Scoring
# 2                     2                  40                  2.7  Scoring
# 3                     0                  36                  2.4  Scoring
# 4                     0                  24                  2.0  Scoring
# ..                  ...                 ...                  ...      ...
# 473                   0                   6                  0.4  Scoring
# 474                   0                   6                  0.7  Scoring
# 475                   0                   6                  1.2  Scoring
# 476                   0                   6                  0.4  Scoring
# 477                   0                   6                  6.0  Scoring
#
#          team
# 0       Bills
# 1       Bills
# 2       Bills
# 3       Bills
# 4       Bills
# ..        ...
# 473  Seahawks
# 474  Seahawks
# 475  Seahawks
# 476  Seahawks
# 477  Seahawks
#
# [478 rows x 14 columns]
