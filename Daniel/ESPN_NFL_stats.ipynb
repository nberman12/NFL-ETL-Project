# %%
from bs4 import *
import requests
import re
import pandas as pd

# %%
df = pd.read_csv("team_links.csv")

# %%
df.stat_links
# Out:
# 0     http://www.espn.com/nfl/team/stats/_/name/buf/...
# 1     http://www.espn.com/nfl/team/stats/_/name/mia/...
# 2     http://www.espn.com/nfl/team/stats/_/name/ne/n...
# 3     http://www.espn.com/nfl/team/stats/_/name/nyj/...
# 4     http://www.espn.com/nfl/team/stats/_/name/bal/...
# 5     http://www.espn.com/nfl/team/stats/_/name/cin/...
# 6     http://www.espn.com/nfl/team/stats/_/name/cle/...
# 7     http://www.espn.com/nfl/team/stats/_/name/pit/...
# 8     http://www.espn.com/nfl/team/stats/_/name/hou/...
# 9     http://www.espn.com/nfl/team/stats/_/name/ind/...
# 10    http://www.espn.com/nfl/team/stats/_/name/jax/...
# 11    http://www.espn.com/nfl/team/stats/_/name/ten/...
# 12    http://www.espn.com/nfl/team/stats/_/name/den/...
# 13    http://www.espn.com/nfl/team/stats/_/name/kc/k...
# 14    http://www.espn.com/nfl/team/stats/_/name/lv/l...
# 15    http://www.espn.com/nfl/team/stats/_/name/lac/...
# 16    http://www.espn.com/nfl/team/stats/_/name/dal/...
# 17    http://www.espn.com/nfl/team/stats/_/name/nyg/...
# 18    http://www.espn.com/nfl/team/stats/_/name/phi/...
# 19    http://www.espn.com/nfl/team/stats/_/name/wsh/...
# 20    http://www.espn.com/nfl/team/stats/_/name/chi/...
# 21    http://www.espn.com/nfl/team/stats/_/name/det/...
# 22    http://www.espn.com/nfl/team/stats/_/name/gb/g...
# 23    http://www.espn.com/nfl/team/stats/_/name/min/...
# 24    http://www.espn.com/nfl/team/stats/_/name/atl/...
# 25    http://www.espn.com/nfl/team/stats/_/name/car/...
# 26    http://www.espn.com/nfl/team/stats/_/name/no/n...
# 27    http://www.espn.com/nfl/team/stats/_/name/tb/t...
# 28    http://www.espn.com/nfl/team/stats/_/name/ari/...
# 29    http://www.espn.com/nfl/team/stats/_/name/lar/...
# 30    http://www.espn.com/nfl/team/stats/_/name/sf/s...
# 31    http://www.espn.com/nfl/team/stats/_/name/sea/...
# Name: stat_links, dtype: object

# %%
master_passing = pd.DataFrame({})
master_rushing = pd.DataFrame({})
master_receiving = pd.DataFrame({})
master_defense = pd.DataFrame({})
master_scoring = pd.DataFrame({})
master_returning = pd.DataFrame({})
master_kicking = pd.DataFrame({})
master_punting = pd.DataFrame({})

for i in range(0,len(df.Team)):
#for i in range(0,2):
    url = df.stat_links[i]
    table=pd.read_html(url)
    
    #collecting 12 tables
    if len(table[0])<2:
        table[0][table[14].keys()[0]]=table[0].keys()[0]
        table[0]=table[0].rename(columns={table[0].keys()[0]:"Name"})
    passing_df = table[0].merge(table[1],left_index=True, right_index=True)
    passing_df["class"]="Passing"
    passing_df["team"]=df.Team[i]
    if len(table[0])>2:    
        passing_df.drop(passing_df.tail(1).index,inplace=True)
    passing_df.reset_index()
    
    if len(table[2])<2:
        table[2][table[14].keys()[0]]=table[2].keys()[0]
        table[2]=table[2].rename(columns={table[2].keys()[0]:"Name"})
    rushing_df = table[2].merge(table[3],left_index=True, right_index=True)
    rushing_df["class"]="Rushing"
    rushing_df["team"]=df.Team[i]
    if len(table[2])>2:    
        rushing_df.drop(rushing_df.tail(1).index,inplace=True)
    rushing_df.reset_index()
    
    if len(table[4])<2:
        table[4][table[4].keys()[0]]=table[4].keys()[0]
        table[4]=table[4].rename(columns={table[4].keys()[0]:"Name"})
    receiving_df = table[4].merge(table[5],left_index=True, right_index=True)
    receiving_df["class"]="Receiving"
    receiving_df["team"]=df.Team[i]
    if len(table[4])>2:    
        receiving_df.drop(receiving_df.tail(1).index,inplace=True)
    receiving_df.reset_index()
    
    if len(table[6])<2:
        table[6][table[6].keys()[0]]=table[6].keys()[0]
        table[6]=table[6].rename(columns={table[6].keys()[0]:"Name"})
    defense_df = table[6].merge(table[7],left_index=True, right_index=True)
    defense_df["class"]="Defense"
    defense_df["team"]=df.Team[i]
    if len(table[6])>2:    
        defense_df.drop(defense_df.tail(1).index,inplace=True)
    defense_df.reset_index()
    
    if len(table[8])<2:
        table[8][table[8].keys()[0]]=table[8].keys()[0]
        table[8]=table[8].rename(columns={table[8].keys()[0]:"Name"})
    scoring_df = table[8].merge(table[9],left_index=True, right_index=True)
    scoring_df["class"]="Scoring"
    scoring_df["team"]=df.Team[i]
    if len(table[8])>2:    
        scoring_df.drop(scoring_df.tail(1).index,inplace=True)
    scoring_df.reset_index()
    
    if len(table[10])<2:
        table[10][table[10].keys()[0]]=table[10].keys()[0]
        table[10]=table[10].rename(columns={table[10].keys()[0]:"Name"})
    returning_df =table[10].merge(table[11],left_index=True, right_index=True)
    returning_df["class"]="Returning"
    returning_df["team"]=df.Team[i]
    if len(table[10])>2:    
        returning_df.drop(returning_df.tail(1).index,inplace=True)
    returning_df.reset_index()
    
    if len(table[12])<2:
        table[12][table[12].keys()[0]]=table[12].keys()[0]
        table[12]=table[12].rename(columns={table[12].keys()[0]:"Name"})
    kicking_df = table[12].merge(table[13],left_index=True, right_index=True)
    kicking_df.reset_index()
    kicking_df["class"]="Kicking"
    kicking_df["team"]=df.Team[i]
    if len(table[12])>2:
        kicking_df.drop(kicking_df.tail(1).index,inplace=True)

    if len(table[14])<3:
        table[14][table[14].keys()[0]]=table[14].keys()[0]
        table[14]=table[14].rename(columns={table[14].keys()[0]:"Name"})
    punting_df = table[14].merge(table[15],left_index=True, right_index=True)
    punting_df.reset_index()
    punting_df["class"]="Punting"
    punting_df["team"]=df.Team[i]
    if len(table[14])>2:
        punting_df.drop(punting_df.tail(1).index,inplace=True)
    
    
    #merge all the tables into master DF
    master_passing=pd.concat([master_passing,passing_df])
    master_rushing=pd.concat([master_rushing,rushing_df])
    master_receiving=pd.concat([master_receiving,receiving_df])
    master_defense=pd.concat([master_defense,defense_df])
    master_scoring=pd.concat([master_scoring,scoring_df])
    master_returning=pd.concat([master_returning,returning_df])
    master_kicking=pd.concat([master_kicking,kicking_df])
    master_punting=pd.concat([master_punting,punting_df])
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:101: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:102: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:103: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:104: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
master_passing.to_csv("passing.csv")
master_rushing.to_csv("rushing.csv")
master_receiving.to_csv("receiving.csv")

master_defense.to_csv("defense.csv")
master_scoring.to_csv("scoring.csv")
master_returning.to_csv("returning.csv")

master_kicking.to_csv("kicking.csv")
master_punting.to_csv("punting.csv")

# %%
#master_passing
#master_rushing
#master_receiving

##############################
#errors found
#############################
#master_punting

#master_defense
#master_scoring
#master_returning
#master_kicking
# Out:
#                    Name  GP  CMP  ATT   CMP%   YDS   AVG  YDS/G  LNG  TD  INT  \
# 0         Josh Allen QB  16  271  461   58.8  3089   6.7  224.9   53  20    9
# 1       Matt Barkley QB   2   27   51   52.9   359   7.0  177.5   41   0    3
# 2         John Brown WR  15    1    1  100.0    28  28.0   73.0   28   1    0
# 0   Ryan Fitzpatrick QB  15  311  502   62.0  3529   7.0  251.5   51  20   13
# 1         Josh Rosen QB   6   58  109   53.2   567   5.2   96.7   40   1    5
# ..                  ...  ..  ...  ...    ...   ...   ...    ...  ...  ..  ...
# 0    Jimmy Garoppolo QB  16  329  476   69.1  3978   8.4  252.5   75  27   13
# 1   Emmanuel Sanders WR  10    1    1  100.0    35  35.0   53.7   35   1    0
# 2       Dante Pettis WR  11    1    1  100.0    16  16.0   11.4   16   0    0
# 0     Russell Wilson QB  16  341  516   66.1  4110   8.0  278.3   60  31    5
# 1        Josh Gordon WR   5    0    1    0.0     0   0.0   27.8    0   0    1
#
#     SACK  SYL    QBR    RTG    class      team
# 0     38  237   45.8   85.3  Passing     Bills
# 1      2   10    9.2   51.0  Passing     Bills
# 2      0    0  100.0  158.3  Passing     Bills
# 0     40  209   64.7   85.5  Passing  Dolphins
# 1     16   93   19.4   52.0  Passing  Dolphins
# ..   ...  ...    ...    ...      ...       ...
# 0     36  237   60.2  102.0  Passing     49ers
# 1      0    0  100.0  158.3  Passing     49ers
# 2      0    0   59.8  118.8  Passing     49ers
# 0     48  319   69.4  106.3  Passing  Seahawks
# 1      0    0    0.0    0.0  Passing  Seahawks
#
# [102 rows x 17 columns]
