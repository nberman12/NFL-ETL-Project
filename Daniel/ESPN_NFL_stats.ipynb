# %%
from bs4 import *
import requests
import re
import pandas as pd

# %%
df = pd.read_csv("team_links.csv")

# %%
master_passing = pd.DataFrame({})
master_rushing = pd.DataFrame({})
master_receiving = pd.DataFrame({})
master_defense = pd.DataFrame({})
master_scoring = pd.DataFrame({})
master_returning = pd.DataFrame({})
master_kicking = pd.DataFrame({})
master_punting = pd.DataFrame({})

for i in range(0,len(df.Team)):
#for i in range(0,2):
    url = df.stat_links[i]
    table=pd.read_html(url)
    
    #collecting 12 tables
    if table[0].keys()[0]!='Name':
        table[0]=table[0].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})
    if len(table[0])<2 or table[0].keys()[0]!='Name':
        table[0][table[14].keys()[0]]=table[0].keys()[0]
        table[0]=table[0].rename(columns={table[0].keys()[0]:"Name"})
    passing_df = table[0].merge(table[1],left_index=True, right_index=True)
    passing_df["class"]="Passing"
    passing_df["team"]=df.Team[i]
    if len(table[0])>1:    
        passing_df.drop(passing_df.tail(1).index,inplace=True)
    passing_df.reset_index(drop=True)
    
    if table[2].keys()[0]!='Name':
        table[2]=table[2].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})    
    if len(table[2])<2 or table[2].keys()[0]!='Name':
        table[2][table[14].keys()[0]]=table[2].keys()[0]
        table[2]=table[2].rename(columns={table[2].keys()[0]:"Name"})
    rushing_df = table[2].merge(table[3],left_index=True, right_index=True)
    rushing_df["class"]="Rushing"
    rushing_df["team"]=df.Team[i]
    if len(table[2])>1:    
        rushing_df.drop(rushing_df.tail(1).index,inplace=True)
    rushing_df.reset_index(drop=True)
    
    if table[4].keys()[0]!='Name':
        table[4]=table[4].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})    
    if len(table[4])<2 or table[4].keys()[0]!='Name':
        table[4][table[4].keys()[0]]=table[4].keys()[0]
        table[4]=table[4].rename(columns={table[4].keys()[0]:"Name"})
    receiving_df = table[4].merge(table[5],left_index=True, right_index=True)
    receiving_df["class"]="Receiving"
    receiving_df["team"]=df.Team[i]
    if len(table[4])>1:    
        receiving_df.drop(receiving_df.tail(1).index,inplace=True)
    receiving_df.reset_index(drop=True)
   ###
    if table[6].keys()[0]!='Name':
        print("working")
        table[6]=table[6].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})    
    if len(table[6])<2 or table[6].keys()[0]!='Name':
        table[6][table[6].keys()[0]]=table[6].keys()[0]
        table[6]=table[6].rename(columns={table[6].keys()[0]:"Name"})
    defense_df = table[6].merge(table[7],left_index=True, right_index=True)
    defense_df["class"]="Defense"
    defense_df["team"]=df.Team[i]
    if len(table[6])>1:    
        defense_df.drop(defense_df.tail(1).index,inplace=True)
    defense_df.reset_index(drop=True)

    if table[8].keys()[0]!='Name':
        table[8]=table[8].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})
    if len(table[8])<2 or table[8].keys()[0]!='Name':
        table[8][table[8].keys()[0]]=table[8].keys()[0]
        table[8]=table[8].rename(columns={table[8].keys()[0]:"Name"})
    scoring_df = table[8].merge(table[9],left_index=True, right_index=True)
    scoring_df["class"]="Scoring"
    scoring_df["team"]=df.Team[i]
    if len(table[8])>1:    
        scoring_df.drop(scoring_df.tail(1).index,inplace=True)
    scoring_df.reset_index(drop=True)

    ####
    if table[10].keys()[0]!='Name':
        table[10]=table[10].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})
    if len(table[10])<2 or table[10].keys()[0]!='Name':
        table[10][table[10].keys()[0]]=table[10].keys()[0]
        table[10]=table[10].rename(columns={table[10].keys()[0]:"Name"})
    returning_df =table[10].merge(table[11],left_index=True, right_index=True)
    returning_df["class"]="Returning"
    returning_df["team"]=df.Team[i]
    if len(table[10])>1:    
        returning_df.drop(returning_df.tail(1).index,inplace=True)
    returning_df.reset_index(drop=True)
    
    if table[12].keys()[0]!='Name':
        table[12]=table[12].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})
    if len(table[12])<2 or  table[12].keys()[0]!='Name':
        table[12][table[12].keys()[0]]=table[12].keys()[0]
        table[12]=table[12].rename(columns={table[12].keys()[0]:"Name"})
    kicking_df = table[12].merge(table[13],left_index=True, right_index=True)
    kicking_df.reset_index()
    kicking_df["class"]="Kicking"
    kicking_df["team"]=df.Team[i]
    if len(table[12])>1:
        kicking_df.drop(kicking_df.tail(1).index,inplace=True)

    if table[14].keys()[0]!='Name':
        table[14].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"}) 
    if len(table[14])<2 or table[14].keys()[0]!='Name':
        table[14][table[14].keys()[0]]=table[14].keys()[0]
        table[14]=table[14].rename(columns={table[14].keys()[0]:"Name"})
    punting_df = table[14].merge(table[15],left_index=True, right_index=True)
    punting_df.reset_index()
    punting_df["class"]="Punting"
    punting_df["team"]=df.Team[i]
    if len(table[14])>1:
        punting_df.drop(punting_df.tail(1).index,inplace=True)
    
    
    #merge all the tables into master DF
    master_passing=pd.concat([master_passing,passing_df])
    master_rushing=pd.concat([master_rushing,rushing_df])
    master_receiving=pd.concat([master_receiving,receiving_df])
    master_defense=pd.concat([master_defense,defense_df])
    master_scoring=pd.concat([master_scoring,scoring_df])
    master_returning=pd.concat([master_returning,returning_df])
    master_kicking=pd.concat([master_kicking,kicking_df])
    master_punting=pd.concat([master_punting,punting_df])
# Out:
# working
# C:\Users\chand\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working
# working

# %%
len(table[14])
# Out:
# 2

# %%
i = 1
url = df.stat_links[i]
table=pd.read_html(url)
if table[6].keys()[0]!='Name':
    print("working")
    table[6]=table[6].T.reset_index().T.reset_index().drop(columns=['index']).rename(columns={0:"Name"})    
if len(table[6])<2 or table[6].keys()[0]!='Name':
    table[6][table[6].keys()[0]]=table[6].keys()[0]
    table[6]=table[6].rename(columns={table[6].keys()[0]:"Name"})
defense_df = table[6].merge(table[7],left_index=True, right_index=True)
defense_df["class"]="Defense"
defense_df["team"]=df.Team[i]
if len(table[6])>1:    
    defense_df.drop(defense_df.tail(1).index,inplace=True)
defense_df.reset_index(drop=True)
# Out:
# working
#                      Name  (Unnamed: 0_level_0, GP)  (Tackles, SOLO)  \
# 0         Jerome Baker LB                        16               76
# 1            Eric Rowe CB                        16               54
# 2       Davon Godchaux DT                        16               33
# 3     Raekwon McMillan LB                        13               35
# 4         Vince Biegel LB                        15               27
# 5          Jamal Perry CB                        14               39
# 6    Christian Wilkins DT                        16               30
# 7          Nik Needham CB                        12               41
# 8         Sam Eguavoen LB                        16               22
# 9         John Jenkins DT                        16               20
# 10         Reshad Jones S                         4               17
# 11         Bobby McCain S                         9               19
# 12          Avery Moss DE                        11               11
# 13          Ryan Lewis CB                         8               19
# 14      Charles Harris DE                        14               11
# 15       Adrian Colbert S                         6               16
# 16        Trent Harris LB                        11               16
# 17          Walt Aikens S                        15               15
# 18       Taco Charlton DE                        10               14
# 19        Steven Parker S                        14               15
# 20         Ken Webster CB                         8               17
# 21       Xavien Howard CB                         5               12
# 22   Andrew Van Ginkel LB                         6               11
# 23       Chris Lammons CB                        12                8
# 24   Minkah Fitzpatrick S                         2                8
# 25         Nate Brooks CB                         3               10
# 26         Zach Sieler DT                         3                3
# 27       Durham Smythe TE                        16                7
# 28       Montre Hartage S                         4                6
# 29       Calvin Munson LB                         2                5
# 30           Tae Hayes CB                         2                4
# 31       Patrick Laird RB                        15                5
# 32         Ken Crawley CB                         4                6
# 33    Johnson Bademosi CB                         4                4
# 34  Jonathan Ledbetter DE                         1                1
# 35          Deon Lacey LB                        16                3
# 36     Linden Stephens CB                         3                3
# 37       Michael Deiter G                        16                3
# 38     De'Lance Turner RB                         8                2
# 39        Jakeem Grant WR                        10                3
# 40      Tank Carradine DE                         1                1
# 41         Allen Hurns WR                        14                2
# 42        Mike Gesicki TE                        16                2
# 43    Preston Williams WR                         8                2
# 44      DeVante Parker WR                        16                2
# 45       Gerald Willis DT                         2                0
# 46        Mack Hollins WR                         4                0
# 47           Matt Haack P                        16                0
# 48   Julie'n Davenport OT                         8                1
# 49      James Crawford LB                         3                0
# 50        Danny Isidora G                         3                1
# 51         Isaiah Ford WR                         8                1
# 52         Jesse Davis OT                        15                1
# 53       Jason Sanders PK                        16                1
# 54       Kalen Ballage RB                        12                0
#
#     (Tackles, AST)  (Tackles, TOT)  (Sacks, SACK)  (Sacks, SCKYDS)  \
# 0               50             126            1.5               13
# 1               27              81            0.0                0
# 2               42              75            2.0                9
# 3               37              72            0.0                0
# 4               32              59            2.5               18
# 5               19              58            0.0                0
# 6               26              56            2.0               14
# 7               13              54            1.0                7
# 8               20              42            3.5               22
# 9               14              34            1.0                7
# 10              10              27            0.0                0
# 11               6              25            0.0                0
# 12              14              25            0.0                0
# 13               5              24            0.0                0
# 14              12              23            0.5                3
# 15               6              22            0.0                0
# 16               6              22            1.5               10
# 17               6              21            0.0                0
# 18               7              21            5.0               34
# 19               5              20            0.0                0
# 20               2              19            0.0                0
# 21               5              17            0.0                0
# 22               4              15            1.0                8
# 23               5              13            0.0                0
# 24               4              12            0.0                0
# 25               1              11            0.0                0
# 26               5               8            1.0                8
# 27               1               8            0.0                0
# 28               2               8            0.0                0
# 29               2               7            0.0                0
# 30               3               7            0.0                0
# 31               1               6            0.0                0
# 32               0               6            0.0                0
# 33               1               5            0.0                0
# 34               3               4            0.5                0
# 35               1               4            0.0                0
# 36               0               3            0.0                0
# 37               0               3            0.0                0
# 38               1               3            0.0                0
# 39               0               3            0.0                0
# 40               2               3            0.0                0
# 41               0               2            0.0                0
# 42               0               2            0.0                0
# 43               0               2            0.0                0
# 44               0               2            0.0                0
# 45               2               2            0.0                0
# 46               1               1            0.0                0
# 47               1               1            0.0                0
# 48               0               1            0.0                0
# 49               1               1            0.0                0
# 50               0               1            0.0                0
# 51               0               1            0.0                0
# 52               0               1            0.0                0
# 53               0               1            0.0                0
# 54               1               1            0.0                0
#
#     (Sacks, TFL)  (Interceptions, PD)  (Interceptions, INT)  \
# 0            6.5                    4                     1
# 1            1.0                    8                     1
# 2            5.0                    1                     0
# 3            2.0                    1                     0
# 4            6.0                    1                     1
# 5            2.5                    6                     1
# 6            4.0                    2                     0
# 7            1.0                   11                     2
# 8            7.0                    1                     0
# 9            2.5                    1                     0
# 10           2.0                    1                     0
# 11           0.0                    3                     2
# 12           0.0                    0                     0
# 13           1.0                    5                     1
# 14           2.5                    0                     0
# 15           0.0                    2                     0
# 16           1.5                    0                     0
# 17           0.0                    1                     0
# 18           5.5                    0                     0
# 19           0.0                    3                     2
# 20           0.0                    1                     0
# 21           0.0                    4                     1
# 22           4.0                    0                     0
# 23           0.0                    3                     1
# 24           0.0                    0                     0
# 25           0.0                    2                     0
# 26           1.0                    2                     0
# 27           0.0                    0                     0
# 28           0.0                    1                     0
# 29           0.0                    0                     0
# 30           0.0                    2                     0
# 31           1.0                    0                     0
# 32           0.0                    0                     0
# 33           0.0                    0                     0
# 34           1.0                    0                     0
# 35           0.0                    0                     0
# 36           0.0                    0                     0
# 37           0.0                    0                     0
# 38           0.0                    0                     0
# 39           0.0                    0                     0
# 40           0.0                    0                     0
# 41           0.0                    0                     0
# 42           0.0                    0                     0
# 43           0.0                    0                     0
# 44           0.0                    0                     0
# 45           0.0                    0                     0
# 46           0.0                    0                     0
# 47           0.0                    0                     0
# 48           0.0                    0                     0
# 49           0.0                    0                     0
# 50           0.0                    0                     0
# 51           0.0                    0                     0
# 52           0.0                    0                     0
# 53           0.0                    0                     0
# 54           0.0                    0                     0
#
#     (Interceptions, YDS)  (Interceptions, LNG)  (Interceptions, TD)  \
# 0                     34                    34                    0
# 1                     35                    35                    1
# 2                      0                     0                    0
# 3                      0                     0                    0
# 4                      7                     7                    0
# 5                      0                     0                    0
# 6                      0                     0                    0
# 7                     23                    23                    0
# 8                      0                     0                    0
# 9                      0                     0                    0
# 10                     0                     0                    0
# 11                    53                    32                    0
# 12                     0                     0                    0
# 13                     3                     3                    0
# 14                     0                     0                    0
# 15                     0                     0                    0
# 16                     0                     0                    0
# 17                     0                     0                    0
# 18                     0                     0                    0
# 19                    35                    35                    0
# 20                     0                     0                    0
# 21                     0                     0                    0
# 22                     0                     0                    0
# 23                     0                     0                    0
# 24                     0                     0                    0
# 25                     0                     0                    0
# 26                     0                     0                    0
# 27                     0                     0                    0
# 28                     0                     0                    0
# 29                     0                     0                    0
# 30                     0                     0                    0
# 31                     0                     0                    0
# 32                     0                     0                    0
# 33                     0                     0                    0
# 34                     0                     0                    0
# 35                     0                     0                    0
# 36                     0                     0                    0
# 37                     0                     0                    0
# 38                     0                     0                    0
# 39                     0                     0                    0
# 40                     0                     0                    0
# 41                     0                     0                    0
# 42                     0                     0                    0
# 43                     0                     0                    0
# 44                     0                     0                    0
# 45                     0                     0                    0
# 46                     0                     0                    0
# 47                     0                     0                    0
# 48                     0                     0                    0
# 49                     0                     0                    0
# 50                     0                     0                    0
# 51                     0                     0                    0
# 52                     0                     0                    0
# 53                     0                     0                    0
# 54                     0                     0                    0
#
#     (Fumbles, FF)  (Fumbles, FR)  (Fumbles, FTD)  (Unnamed: 15_level_0, KB)  \
# 0               2              0               0                          0
# 1               1              0               0                          0
# 2               0              0               0                          0
# 3               0              0               0                          0
# 4               0              0               0                          0
# 5               0              0               0                          0
# 6               0              0               0                          0
# 7               1              0               0                          0
# 8               0              1               0                          0
# 9               0              0               0                          0
# 10              0              0               0                          0
# 11              0              0               0                          0
# 12              1              0               0                          0
# 13              0              0               0                          0
# 14              0              0               0                          0
# 15              0              0               0                          0
# 16              1              0               0                          0
# 17              0              0               0                          0
# 18              2              0               0                          0
# 19              0              0               0                          0
# 20              0              0               0                          0
# 21              0              0               0                          0
# 22              0              1               0                          0
# 23              0              0               0                          0
# 24              1              1               0                          0
# 25              0              0               0                          0
# 26              0              0               0                          0
# 27              0              0               0                          0
# 28              0              0               0                          0
# 29              0              0               0                          0
# 30              0              0               0                          0
# 31              0              0               0                          0
# 32              0              0               0                          0
# 33              0              0               0                          0
# 34              0              0               0                          0
# 35              0              0               0                          0
# 36              0              0               0                          0
# 37              0              0               0                          0
# 38              0              0               0                          0
# 39              0              0               0                          0
# 40              0              0               0                          0
# 41              0              0               0                          0
# 42              0              0               0                          0
# 43              0              0               0                          0
# 44              0              0               0                          0
# 45              0              0               0                          0
# 46              0              0               0                          0
# 47              0              0               0                          0
# 48              0              0               0                          0
# 49              0              0               0                          0
# 50              0              0               0                          0
# 51              0              0               0                          0
# 52              0              0               0                          0
# 53              0              0               0                          0
# 54              0              0               0                          0
#
#       class      team
# 0   Defense  Dolphins
# 1   Defense  Dolphins
# 2   Defense  Dolphins
# 3   Defense  Dolphins
# 4   Defense  Dolphins
# 5   Defense  Dolphins
# 6   Defense  Dolphins
# 7   Defense  Dolphins
# 8   Defense  Dolphins
# 9   Defense  Dolphins
# 10  Defense  Dolphins
# 11  Defense  Dolphins
# 12  Defense  Dolphins
# 13  Defense  Dolphins
# 14  Defense  Dolphins
# 15  Defense  Dolphins
# 16  Defense  Dolphins
# 17  Defense  Dolphins
# 18  Defense  Dolphins
# 19  Defense  Dolphins
# 20  Defense  Dolphins
# 21  Defense  Dolphins
# 22  Defense  Dolphins
# 23  Defense  Dolphins
# 24  Defense  Dolphins
# 25  Defense  Dolphins
# 26  Defense  Dolphins
# 27  Defense  Dolphins
# 28  Defense  Dolphins
# 29  Defense  Dolphins
# 30  Defense  Dolphins
# 31  Defense  Dolphins
# 32  Defense  Dolphins
# 33  Defense  Dolphins
# 34  Defense  Dolphins
# 35  Defense  Dolphins
# 36  Defense  Dolphins
# 37  Defense  Dolphins
# 38  Defense  Dolphins
# 39  Defense  Dolphins
# 40  Defense  Dolphins
# 41  Defense  Dolphins
# 42  Defense  Dolphins
# 43  Defense  Dolphins
# 44  Defense  Dolphins
# 45  Defense  Dolphins
# 46  Defense  Dolphins
# 47  Defense  Dolphins
# 48  Defense  Dolphins
# 49  Defense  Dolphins
# 50  Defense  Dolphins
# 51  Defense  Dolphins
# 52  Defense  Dolphins
# 53  Defense  Dolphins
# 54  Defense  Dolphins

# %%
# Out:
#   File "<ipython-input-6-8ed3e6acfcb1>", line 1
#     table[
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
master_passing=master_passing.reset_index(drop=True)
master_rushing=master_rushing.reset_index(drop=True)
master_receiving=master_receiving.reset_index(drop=True)
master_defense=master_defense.reset_index(drop=True)
master_scoring=master_scoring.reset_index(drop=True)
master_returning=master_returning.reset_index(drop=True)
master_kicking=master_kicking.reset_index(drop=True)
master_punting=master_punting.reset_index(drop=True)

master_passing.to_csv("stats/passing.csv")
master_rushing.to_csv("stats/rushing.csv")
master_receiving.to_csv("stats/receiving.csv")
master_defense.to_csv("stats/defense.csv")
master_scoring.to_csv("stats/scoring.csv")
master_returning.to_csv("stats/returning.csv")
master_kicking.to_csv("stats/kicking.csv")
master_punting.to_csv("stats/punting.csv")

# %%
master_kicking
