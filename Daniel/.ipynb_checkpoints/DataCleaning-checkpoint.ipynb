# %%
import pandas as pd

# %%
defense= pd.read_csv("roster/defense.csv")
offense= pd.read_csv("roster/offense.csv")
special= pd.read_csv("roster/special.csv")

# %%
players_df = pd.concat([defense,offense])
players_df = pd.concat([players_df,special])
players_df = players_df.drop(columns=['Unnamed: 0']).reset_index(drop=True)

# %%
import re 
  
def remove(list): 
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list] 
    return list
players_df["FullName"]=remove(players_df.Name)

# %%
first = []
last = []

test = [name.split for name in players_df.FullName]
for name in players_df.FullName:
    name_split = name.split(' ')
    if len(name_split)<3:
        
        first.append(name_split[0])
        last.append(name_split[1])
    else:
        first.append(name_split[0])
        last.append(name_split[1]+" " +name_split[2])

players_df["First Name"] = first
players_df["Last Name"] = last

# %%
team_abv_list = []
for i in range(0,len(players_df.team)):
    x = True
    for j in range(0,len(team_df.Team)):
        
        if players_df.team[i] in team_df.Team[j] and x == True:
                   
            team_abv_list.append(team_df.TM[j])
            x=False
                   
            
            
players_df['TeamID']=team_abv_list
players_df = players_df.rename(columns={"Name":"PlayerID"})

# %%
players_df = players_df.drop(columns=['team'])

# %%
players_df.to_csv("temp/players_df.csv")

# %%
len(players_df)
# Out:
# 2840

# %%
metrics
# Out:
#                   Name  Height   Weight Forty Yard Dash Shuttle Time  \
# 0            Tom Brady   6' 4"  225 lbs        5.28 sec     4.38 sec
# 1           Drew Brees   6' 0"  209 lbs        4.83 sec     4.21 sec
# 2           Will Allen  5' 10"  192 lbs        4.58 sec     4.25 sec
# 3         Reggie Wayne   6' 0"  203 lbs        4.45 sec          NaN
# 4          Steve Smith   5' 9"  195 lbs        4.44 sec     4.19 sec
# ...                ...     ...      ...             ...          ...
# 3646       Evan Weaver   6' 2"  237 lbs        4.76 sec     4.21 sec
# 3647     Casey Toohill   6' 4"  250 lbs        4.62 sec     4.21 sec
# 3648      Mykal Walker   6' 3"  230 lbs        4.65 sec     4.25 sec
# 3649  Chapelle Russell   6' 2"  236 lbs        4.69 sec     4.41 sec
# 3650     Justin Strnad   6' 3"  238 lbs        4.74 sec     4.49 sec
#
#      Vertical Jump Broad Jump Bench Press Cone Drill
# 0          24.5 in      99 in         NaN   7.20 sec
# ...

# %%
players_df.head()
# Out:
#            PlayerID POS Age     HT       WT Exp             College   team  \
# 0   Mario Addison97  DE  32  6' 3"  260 lbs  10                Troy  Bills
# 1   Bryan Cox Jr.94  DE  25  6' 3"  270 lbs   4             Florida  Bills
# 2      AJ Epenesa57  DE  21  6' 6"  280 lbs   R                Iowa  Bills
# 3    Jerry Hughes55  DE  31  6' 2"  254 lbs  11                 TCU  Bills
# 4  Darryl Johnson92  DE  23  6' 6"  253 lbs   2  North Carolina A&T  Bills
#
#          FullName First Name Last Name TeamID
# 0   Mario Addison      Mario   Addison    BUF
# 1   Bryan Cox Jr.      Bryan   Cox Jr.    BUF
# 2      AJ Epenesa         AJ   Epenesa    BUF
# 3    Jerry Hughes      Jerry    Hughes    BUF
# 4  Darryl Johnson     Darryl   Johnson    BUF

# %%
#Player Metrics

# %%
metric = pd.read_csv("rotowire/cleaned_rotowire2.csv")

# %%
metrics = metric[["Name", "Height", "Weight", "Forty Yard Dash", "Shuttle Time", "Vertical Jump", "Broad Jump", "Bench Press", "Cone Drill"]]


metric_merge = metrics.merge(players_df, left_on='Name', right_on="FullName", how = 'inner')
metric_merge = metric_merge[["PlayerID","Name", "Height", "Weight", "Forty Yard Dash", "Shuttle Time", "Vertical Jump", "Broad Jump", "Bench Press", "Cone Drill"]]
metric_merge = metric_merge.drop(columns=['Name'])
metric_merge.to_csv("temp/metrics_df.csv")

# %%
metric_merge
# Out:
#                 PlayerID Height   Weight Forty Yard Dash Shuttle Time  \
# 0            Tom Brady12  6' 4"  225 lbs        5.28 sec     4.38 sec
# 1            Drew Brees9  6' 0"  209 lbs        4.83 sec     4.21 sec
# 2         Jason Witten82  6' 6"  263 lbs        4.65 sec          NaN
# 3     Larry Fitzgerald11  6' 3"  218 lbs        4.48 sec     4.28 sec
# 4        Mike Williams81  6' 5"  229 lbs        4.53 sec     4.31 sec
# ...                  ...    ...      ...             ...          ...
# 1551       Evan Weaver50  6' 2"  237 lbs        4.76 sec     4.21 sec
# 1552     Casey Toohill52  6' 4"  250 lbs        4.62 sec     4.21 sec
# 1553      Mykal Walker43  6' 3"  230 lbs        4.65 sec     4.25 sec
# 1554  Chapelle Russell53  6' 2"  236 lbs        4.69 sec     4.41 sec
# 1555     Justin Strnad23  6' 3"  238 lbs        4.74 sec     4.49 sec
#
#      Vertical Jump Broad Jump Bench Press Cone Drill
# 0          24.5 in      99 in         NaN   7.20 sec
# ...

# %%
defense_df = pd.read_csv("stats/defense.csv")
kicking_df = pd.read_csv("stats/kicking.csv")
passing_df = pd.read_csv("stats/passing.csv")
punting_df = pd.read_csv("stats/punting.csv")
receiving_df = pd.read_csv("stats/receiving.csv")
returning_df = pd.read_csv("stats/returning.csv")
rushing_df = pd.read_csv("stats/rushing.csv")
scoring_df = pd.read_csv("stats/scoring.csv")

# %%
# defense_df = defense_df.drop(columns=["Unnamed: 0"])
kicking_df = kicking_df.drop(columns=["Unnamed: 0"])
passing_df = passing_df.drop(columns=["Unnamed: 0"])
punting_df = punting_df.drop(columns=["Unnamed: 0"])
receiving_df = receiving_df.drop(columns=["Unnamed: 0"])
returning_df = returning_df.drop(columns=["Unnamed: 0"])
rushing_df = rushing_df.drop(columns=["Unnamed: 0"])
scoring_df = scoring_df.drop(columns=["Unnamed: 0"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-b6ff36e59714> in <module>
#       1 # defense_df = defense_df.drop(columns=["Unnamed: 0"])
# ----> 2 kicking_df = kicking_df.drop(columns=["Unnamed: 0"])
#       3 passing_df = passing_df.drop(columns=["Unnamed: 0"])
#       4 punting_df = punting_df.drop(columns=["Unnamed: 0"])
#       5 receiving_df = receiving_df.drop(columns=["Unnamed: 0"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
# ...

# %%
defense_df = pd.read_csv("stats/defense.csv")
defense_df = defense_df.drop(columns=["Unnamed: 0"])

# %%
defense_df
# Out:
#                      Name  ('Unnamed: 0_level_0', 'GP')  ('Tackles', 'SOLO')  \
# 0     Tremaine Edmunds LB                            16                   66
# 1          Jordan Poyer S                            16                   71
# 2          Matt Milano LB                            15                   65
# 3         Levi Wallace CB                            16                   66
# 4            Micah Hyde S                            16                   50
# ...                   ...                           ...                  ...
# 1484    Russell Wilson QB                            16                    1
# 1485       George Fant OT                            16                    1
# 1486      Malik Turner WR                            15                    1
# 1487         Ryan Neal CB                             3                    1
# 1488       Duane Brown OT                            12                    1
#
# ...

# %%
defense_df = defense_df.rename(columns={
    "('Unnamed: 0_level_0', 'GP')":"GP",
    "('Tackles', 'SOLO')":"TACKLES_SOLO",
    "('Tackles', 'AST')":"TACKLES_AST",
    "('Tackles', 'TOT')":"TACKLES_TOT",
    "('Sacks', 'SACK')":"SACKS",
    "('Sacks', 'SCKYDS')":"SACKS_SCKYDS",
    "('Sacks', 'TFL')":"SACKS_TFL",
    "('Interceptions', 'PD')":"INTERCEPTIONS_PD",
    "('Interceptions', 'INT')":"INTERCEPTIONS_INT",
    "('Interceptions', 'YDS')":"INTERCEPTIONS_YDS",
    "('Interceptions', 'LNG')":"INTERCEPTIONS_LNG",
    "('Interceptions', 'TD')":"INTERCEPTIONS_TD",
    "('Fumbles', 'FF')":"FUMBLES_FF",
    "('Fumbles', 'FR')":"FUMBLES_FR",
    "('Fumbles', 'FTD')":"FUMBLES_FTD",
    "('Unnamed: 15_level_0', 'KB')":"KB"
                         })

# %%
defense_df
# Out:
#                      Name  GP  TACKLES_SOLO  TACKLES_AST  TACKLES_TOT  SACKS  \
# 0     Tremaine Edmunds LB  16            66           49          115    1.5
# 1          Jordan Poyer S  16            71           36          107    1.0
# 2          Matt Milano LB  15            65           36          101    1.5
# 3         Levi Wallace CB  16            66           10           76    0.0
# 4            Micah Hyde S  16            50           22           72    0.0
# ...                   ...  ..           ...          ...          ...    ...
# 1484    Russell Wilson QB  16             1            0            1    0.0
# 1485       George Fant OT  16             1            0            1    0.0
# 1486      Malik Turner WR  15             1            0            1    0.0
# 1487         Ryan Neal CB   3             1            0            1    0.0
# 1488       Duane Brown OT  12             1            0            1    0.0
#
# ...

# %%
defense_df = defense_df.drop(columns=['class','team'])

# %%
for i in range(0,len(defense_df.Name)):
    defense_df.Name[i]=defense_df.Name[i].replace(defense_df.Name[i].split(" ").pop(-1),"").strip()

defense_df
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   Name  GP  TACKLES_SOLO  TACKLES_AST  TACKLES_TOT  SACKS  \
# 0     Tremaine Edmunds  16            66           49          115    1.5
# 1         Jordan Poyer  16            71           36          107    1.0
# 2          Matt Milano  15            65           36          101    1.5
# 3         Levi Wallace  16            66           10           76    0.0
# 4           Micah Hyde  16            50           22           72    0.0
# ...                ...  ..           ...          ...          ...    ...
# 1484    Russell Wilson  16             1            0            1    0.0
# 1485       George Fant  16             1            0            1    0.0
# ...

# %%
defense_df = defense_df.merge(players_df, left_on='Name',right_on="FullName", how = 'inner')

# %%
defense_df.head(1)
# Out:
#                Name  GP  TACKLES_SOLO  TACKLES_AST  TACKLES_TOT  SACKS  \
# 0  Tremaine Edmunds  16            66           49          115    1.5
#
#    SACKS_SCKYDS  SACKS_TFL  INTERCEPTIONS_PD  INTERCEPTIONS_INT  ...  Age  \
# 0            11       11.5                 9                  1  ...   22
#
#       HT       WT  Exp        College   team          FullName First Name  \
# 0  6' 5"  250 lbs    3  Virginia Tech  Bills  Tremaine Edmunds   Tremaine
#
#   Last Name TeamID
# 0   Edmunds    BUF
#
# [1 rows x 29 columns]

# %%
defense_df = defense_df.drop(columns=["Age","HT","WT","Exp","College","team","FullName","First Name","Last Name","TeamID",'POS','Name'])
defense_df.to_csv("temp/defense_df.csv")

# %%
defense_df
# Out:
#       GP  TACKLES_SOLO  TACKLES_AST  TACKLES_TOT  SACKS  SACKS_SCKYDS  \
# 0     16            66           49          115    1.5            11
# 1     16            71           36          107    1.0             5
# 2     15            65           36          101    1.5            12
# 3     16            66           10           76    0.0             0
# 4     16            50           22           72    0.0             0
# ...   ..           ...          ...          ...    ...           ...
# 1269  16             1            0            1    0.0             0
# 1270  16             1            0            1    0.0             0
# 1271  16             1            0            1    0.0             0
# 1272   3             1            0            1    0.0             0
# 1273  12             1            0            1    0.0             0
#
#       SACKS_TFL  INTERCEPTIONS_PD  INTERCEPTIONS_INT  INTERCEPTIONS_YDS  \
# ...

# %%
defense_df.to_csv("temp/defense_df.csv")

# %%
kicking_df = kicking_df.rename(columns={
    "('Unnamed: 0_level_0', 'GP')":"GP",
    "('Field Goals', 'FGM')":"FGM",
    "('Field Goals', 'FGA')":"FGA",
    "('Field Goals', 'FG%')":"FG%",
    "('Field Goals', 'LNG')":"LNG",
    "('Field Goals', '1-19')":"FG_01-19",
    "('Field Goals', '20-29')":"FG_20-29",
    "('Field Goals', '30-39')":"FG_30-39",
    "('Field Goals', '40-49')":"FG_40-49",
    "('Field Goals', '50+')":"FG_50+",
    "('Extra points', 'XPM')":"XPM",
    "('Extra points', 'XPA')":"XPA",
    "('Extra points', 'XP%')":"XP%"})

# %%
id_df = players_df[['PlayerID','FullName']]

# %%
for i in range(0,len(kicking_df.Name)):
    kicking_df.Name[i]=kicking_df.Name[i].replace(kicking_df.Name[i].split(" ").pop(-1),"").strip()

kicking_df
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Unnamed: 0                Name  GP  FGM  FGA    FG%  LNG FG_01-19  \
# 0            0    Stephen Hauschka  16   22   28   78.6   51      0-0
# 1            1       Jason Sanders  16   23   30   76.7   54      0-0
# 2            2           Nick Folk   7   14   17   82.4   51      1-1
# 3            3  Stephen Gostkowski   4    7    8   87.5   41      0-0
# 4            4         Mike Nugent   4    5    8   62.5   37      0-0
# 5            5         Kai Forbath   1    1    1  100.0   23      0-0
# 6            6          Sam Ficken  15   19   27   70.4   54      0-0
# 7            7       Justin Tucker  16   28   29   96.6   51      0-0
# ...

# %%
kicking_df = kicking_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')
#kicking_df.drop(columns=['Unnamed: 0', 'Name', 'class', 'team', 'FullName'])

# %%
kicking_df = kicking_df.drop(columns=["Unnamed: 0","class","team","FullName","Name"])
kicking_df.to_csv("temp/kicking_df.csv")

# %%
# defense_df = pd.read_csv("stats/defense.csv")
# kicking_df = pd.read_csv("stats/kicking.csv")
passing_df = pd.read_csv("stats/passing.csv")
punting_df = pd.read_csv("stats/punting.csv")
receiving_df = pd.read_csv("stats/receiving.csv")
returning_df = pd.read_csv("stats/returning.csv")
rushing_df = pd.read_csv("stats/rushing.csv")
scoring_df = pd.read_csv("stats/scoring.csv")

# %%
passing_df = passing_df.drop(columns=['Unnamed: 0','class','team'])

# %%
for i in range(0,len(passing_df.Name)):
    passing_df.Name[i]=passing_df.Name[i].replace(passing_df.Name[i].split(" ").pop(-1),"").strip()

passing_df
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  Name  GP  CMP  ATT   CMP%   YDS   AVG  YDS/G  LNG  TD  INT  \
# 0          Josh Allen  16  271  461   58.8  3089   6.7  224.9   53  20    9
# 1        Matt Barkley   2   27   51   52.9   359   7.0  177.5   41   0    3
# 2          John Brown  15    1    1  100.0    28  28.0   73.0   28   1    0
# 3    Ryan Fitzpatrick  15  311  502   62.0  3529   7.0  251.5   51  20   13
# 4          Josh Rosen   6   58  109   53.2   567   5.2   96.7   40   1    5
# ..                ...  ..  ...  ...    ...   ...   ...    ...  ...  ..  ...
# 97    Jimmy Garoppolo  16  329  476   69.1  3978   8.4  252.5   75  27   13
# ...

# %%
id_df
# Out:
# PlayerID    2840
# FullName    2840
# dtype: int64

# %%
passing_df = passing_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')
# Out:
#                 Name  GP  CMP  ATT   CMP%   YDS   AVG  YDS/G  LNG  TD  INT  \
# 0         Josh Allen  16  271  461   58.8  3089   6.7  224.9   53  20    9
# 1         Josh Allen  16  271  461   58.8  3089   6.7  224.9   53  20    9
# 2       Matt Barkley   2   27   51   52.9   359   7.0  177.5   41   0    3
# 3         John Brown  15    1    1  100.0    28  28.0   73.0   28   1    0
# 4   Ryan Fitzpatrick  15  311  502   62.0  3529   7.0  251.5   51  20   13
# ..               ...  ..  ...  ...    ...   ...   ...    ...  ...  ..  ...
# 85       Cooper Kupp  16    0    1    0.0     0   0.0   72.8    0   0    0
# 86   Jimmy Garoppolo  16  329  476   69.1  3978   8.4  252.5   75  27   13
# 87  Emmanuel Sanders  10    1    1  100.0    35  35.0   53.7   35   1    0
# 88      Dante Pettis  11    1    1  100.0    16  16.0   11.4   16   0    0
# 89    Russell Wilson  16  341  516   66.1  4110   8.0  278.3   60  31    5
#
#     SACK  SYL    QBR    RTG            PlayerID          FullName
# ...

# %%
passing_df = passing_df.drop(columns=["Name","FullName"])
passing_df.to_csv("temp/passing_df.csv")

# %%
# defense_df = pd.read_csv("stats/defense.csv")
# kicking_df = pd.read_csv("stats/kicking.csv")
# passing_df = pd.read_csv("stats/passing.csv")
# punting_df = pd.read_csv("stats/punting.csv")
# receiving_df = pd.read_csv("stats/receiving.csv")
returning_df = pd.read_csv("stats/returning.csv")
# rushing_df = pd.read_csv("stats/rushing.csv")
scoring_df = pd.read_csv("stats/scoring.csv")

# %%
punting_df = punting_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(punting_df.Name)):
    punting_df.Name[i]=punting_df.Name[i].replace(punting_df.Name[i].split(" ").pop(-1),"").strip()

punting_df = punting_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

punting_df = punting_df.drop(columns=["Name","FullName"])


receiving_df = receiving_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(receiving_df.Name)):
    receiving_df.Name[i]=receiving_df.Name[i].replace(receiving_df.Name[i].split(" ").pop(-1),"").strip()

receiving_df = receiving_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

receiving_df = receiving_df.drop(columns=["Name","FullName"])

rushing_df = rushing_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(rushing_df.Name)):
    rushing_df.Name[i]=rushing_df.Name[i].replace(rushing_df.Name[i].split(" ").pop(-1),"").strip()

rushing_df = rushing_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

rushing_df = rushing_df.drop(columns=["Name","FullName"])
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
punting_df.to_csv("temp/punting_df.csv")
receiving_df.to_csv("temp/receiving_df.csv")
rushing_df.to_csv("temp/rushing_df.csv")

# %% [markdown]
# scoring_df.rename({"Name":"test"})

# %%
scoring_df = scoring_df.rename(columns={
    "('Unnamed: 0_level_0', 'GP')":"GP",
    "('Touchdowns', 'RUSH')":"TD_RUSH",
    "('Touchdowns', 'REC')":"TD_REC",
    "('Touchdowns', 'RET')":"TD_RET",
    "('Touchdowns', 'TD')":"TD",
    "('Scoring', 'FG')":"SCORING_FG",
    "('Scoring', 'PAT')":"SCORING_PAT",
    "('Scoring', '2PT')":"SCORING_2PT",
    "('Scoring', 'PTS')":"SCORING_PTS",
    "('Scoring', 'TP/G')":"SCORING_TP/G"})


returning_df = returning_df.rename(columns={
    "('Unnamed: 0_level_0', 'GP')":"GP",
    "('Kickoffs', 'ATT')":"KO_ATT",
    "('Kickoffs', 'YDS')":"KO_YDS",
    "('Kickoffs', 'AVG')":"KO_AVG",
    "('Kickoffs', 'LNG')":"KO_LNG",
    "('Kickoffs', 'TD')":"KO_TD",
    "('Punts', 'ATT')":"PUNTS_ATT",
    "('Punts', 'YDS')":"PUNTS_YDS",
    "('Punts', 'AVG')":"PUNTS_AVG",
    "('Punts', 'LNG')":"PUNTS_LNG",
    "('Punts', 'TD')":"PUNTS_TD",
    "('Punts', 'FC')":"PUNTS_FC"
})

# %%
#############################################

# %%
punting_df = pd.read_csv("stats/punting.csv")
punting_df
# Out:
#     Unnamed: 0                 Name  GP  PUNTS   YDS  LNG   AVG   NET  PBLK  \
# 0            0    Corey Bojorquez P  16     79  3313   67  41.9  37.7     1
# 1            1         Matt Haack P  16     69  3105   62  45.0  41.1     0
# 2            2        Jake Bailey P  16     81  3638   65  44.9  41.3     0
# 3            3    Lachlan Edwards P  16     87  3991   63  45.9  41.6     0
# 4            4           Sam Koch P  16     40  1855   62  46.4  39.8     1
# 5            5        Kevin Huber P  16     75  3394   63  45.3  42.1     0
# 6            6       Jamie Gillan P  16     63  2913   71  46.2  41.6     1
# 7            7    Austin Seibert PK  16      1    37   37  37.0  37.0     0
# 8            8       Jordan Berry P  16     74  3368   69  45.5  40.9     0
# 9            9        Bryan Anger P  14     45  2094   71  46.5  44.5     0
# 10          10      Trevor Daniel P   2     11   479   54  43.5  40.9     0
# ...

# %%
#punting_df.read_csv("temp/punting_df.csv")
punting_df=punting_df.rename(columns={
    "YDS":"PUNT_YDS",
    "AVG":"PUNT_AVG",
    "YDS.1":"RETURN_YDS",
    "AVG.1":"RETURN_AVG"
})
punting_df.head()
# Out:
# Empty DataFrame
# Columns: [Name, GP, PUNTS, PUNT_YDS, LNG, PUNT_AVG, NET, PBLK, IN20, TB, FC, ATT, RETURN_YDS, RETURN_AVG, PlayerID, FullName]
# Index: []

# %%
id_df
# Out:
#                PlayerID          FullName
# 0       Mario Addison97     Mario Addison
# 1       Bryan Cox Jr.94     Bryan Cox Jr.
# 2          AJ Epenesa57        AJ Epenesa
# 3        Jerry Hughes55      Jerry Hughes
# 4      Darryl Johnson92    Darryl Johnson
# ...                 ...               ...
# 2835  Mitch Wishnowsky6  Mitch Wishnowsky
# 2836      Kyle Nelson86       Kyle Nelson
# 2837       Jason Myers5       Jason Myers
# 2838   Michael Dickson4   Michael Dickson
# 2839        Tyler Ott69         Tyler Ott
#
# [2840 rows x 2 columns]

# %%
punting_df=pd.read_csv("stats/punting.csv")

punting_df=punting_df.rename(columns={
    "YDS":"PUNT_YDS",
    "AVG":"PUNT_AVG",
    "YDS.1":"RETURN_YDS",
    "AVG.1":"RETURN_AVG"
})
punting_df = punting_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(punting_df.Name)):
    punting_df.Name[i]=punting_df.Name[i].replace(punting_df.Name[i].split(" ").pop(-1),"").strip()

punting_df = punting_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

punting_df = punting_df.drop(columns=["Name","FullName"])

punting_df.to_csv("temp/punting_df.csv")
punting_df
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#     GP  PUNTS  PUNT_YDS  LNG  PUNT_AVG   NET  PBLK  IN20  TB  FC  ATT  \
# 0   16     79      3313   67      41.9  37.7     1    34   7  26   18
# 1   16     69      3105   62      45.0  41.1     0    23   2  20   29
# 2   16     81      3638   65      44.9  41.3     0    36   6  18   28
# 3   16     40      1855   62      46.4  39.8     1    21   4  10   15
# 4   16     75      3394   63      45.3  42.1     0    30   5  30   24
# 5   16     63      2913   71      46.2  41.6     1    28   5  18   20
# 6   16      1        37   37      37.0  37.0     0     1   0   0    0
# 7   16     74      3368   69      45.5  40.9     0    24   4  24   29
# ...

# %%
punting_df=pd.read_csv("stats/punting.csv")

punting_df=punting_df.rename(columns={
    "YDS":"PUNT_YDS",
    "AVG":"PUNT_AVG",
    "YDS.1":"RETURN_YDS",
    "AVG.1":"RETURN_AVG"
})
for i in range(0,len(punting_df.Name)):
    print(punting_df.Name[i].replace(scoring_df.Name[i].split(" ").pop(-1),"").strip())
# Out:
# Corey Bojorquez P
# Matt Haack P
# Jake Bailey P
# Lachlan Edwards P
# Sam Koch P
# Kevin Huber P
# Jamie Gillan P
# Austin Seibert PK
# Jordan Berry P
# Bryan Anger P
# Trevor Daniel P
# Ka'imi Fairbairn PK
# Rigoberto anchez P
# Logan Cooke P
# Brett Kern P
# Colby Wadman P
# Dustin Colquitt P
# AJ Cole P
# Ty Long P
# Chris Jones P
# Riley Dixon P
# Cameron Johnston P
# Tress Way P
# Pat O'Donnell P
# Sam Martin P
# JK Scott P
# Britton Colquitt P
# Ryan Allen P
# Matt Bosher P
# Kasey Redfern P
# Matt Wile P
# Michael Palardy P
# Thomas Morstead P
# Bradley Pinion P
# Andy Lee P
# Ryan Winslow P
# Zane Gonzalez PK
# Johnny Hekker P
# Mitch Wishnowsky P
# Michael Dickson P

# %%
scoring_df = scoring_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(scoring_df.Name)):
    scoring_df.Name[i]=scoring_df.Name[i].replace(scoring_df.Name[i].split(" ").pop(-1),"").strip()

scoring_df = scoring_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

scoring_df = scoring_df.drop(columns=["Name","FullName"])


returning_df = returning_df.drop(columns=['Unnamed: 0','class','team'])

for i in range(0,len(returning_df.Name)):
    returning_df.Name[i]=returning_df.Name[i].replace(returning_df.Name[i].split(" ").pop(-1),"").strip()

returning_df = returning_df.merge(id_df, left_on='Name',right_on="FullName", how = 'inner')

returning_df = returning_df.drop(columns=["Name","FullName"])
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
scoring_df.to_csv("temp/scoring_df.csv")
returning_df.to_csv("temp/returning_df.csv")

# %%
db_df = pd.read_csv("fantasy/db.csv")
dl_df = pd.read_csv("fantasy/dl.csv")
dst_df = pd.read_csv("fantasy/dst.csv")
lb_df = pd.read_csv("fantasy/lb.csv")
qb_df = pd.read_csv("fantasy/qb.csv")
rb_df = pd.read_csv("fantasy/rb.csv")
te_df = pd.read_csv("fantasy/te.csv")
wr_df = pd.read_csv("fantasy/wr.csv")

# %%
rb_df = rb_df.rename(columns = {
    "ATT":"RUSH_ATT",
    "YDS":"RUSH_YDS",
    "Y/A":"RUSH_Y/A",
    "LG":"RUSH_LG",
    "20+":"RUSH_20+",
    "TD":"RUSH_TD",
    "REC":"REC",
    "TGT":"REC_TGT",
    "YDS.1":"REC_YDS",
    "Y/R":"REC_Y/R",
    "TD.1":"REC_TD",
    "FL":"FL",
    "G":"G",
    "FPTS":"FPTS",
    "FPTS/G":"FPTS/G"
})
wr_df = wr_df.rename(columns = {
    "REC":"REC",
    "TGT":"REC_TGT",
    "YDS":"REC_YDS",
    "Y/R":"REC_Y/R",
    "LG":"REC_LG",
    "20+":"REC_20+",
    "TD":"REC_TD",
    "ATT":"RUSH_ATT",
    "YDS.1":"RUSH_YDS",
    "TD.1":"RUSH_TD",
    "FL":"FL",
    "G":"G",
    "FPTS":"FPTS",
    "FPTS/G":"FPTS/G"
})
qb_df = qb_df.rename(columns = {
    "CMP":"PASS_CMP",
    "ATT":"PASS_ATT",
    "PCT":"PASS_PCT",
    "YDS":"PASS_YDS",
    "Y/A":"PASS_Y/A",
    "TD":"PASS_TD",
    "INT":"PASS_INT",
    "SACKS":"PASS_SACKS",
    "ATT.1":"RUSH_ATT",
    "YDS.1":"RUSH_YDS",
    "TD.1":"RUSH_TD",
    "FL":"FL",
    "G":"G",
    "FPTS":"FPTS",
    "FPTS/G":"FPTS/G"
})

te_df=te_df.rename(columns = {
    "REC":"REC",
    "TGT":"REC_TGT",
    "YDS":"REC_YDS",
    "Y/R":"REC_Y/R",
    "LG":"REC_LG",
    "20+":"REC_20+",
    "TD":"REC_TD",
    "ATT":"RUSH_ATT",
    "YDS.1":"RUSH_YDS",
    "TD.1":"RUSH_TD"
})

# %%
for i in range(0,len(wr_df.Player)):
    wr_df.Player[i]=wr_df.Player[i].replace(wr_df.Player[i].split(" ").pop(-1),"").strip()

wr_df = wr_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

wr_df = wr_df.drop(columns=["Player","FullName","Unnamed: 0"])



for i in range(0,len(rb_df.Player)):
    rb_df.Player[i]=rb_df.Player[i].replace(rb_df.Player[i].split(" ").pop(-1),"").strip()

rb_df = rb_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

rb_df = rb_df.drop(columns=["Player","FullName","Unnamed: 0"])



for i in range(0,len(qb_df.Player)):
    qb_df.Player[i]=qb_df.Player[i].replace(qb_df.Player[i].split(" ").pop(-1),"").strip()

qb_df = qb_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

qb_df = qb_df.drop(columns=["Player","FullName","Unnamed: 0"])



for i in range(0,len(lb_df.Player)):
    lb_df.Player[i]=lb_df.Player[i].replace(lb_df.Player[i].split(" ").pop(-1),"").strip()

lb_df = lb_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

lb_df = lb_df.drop(columns=["Player","FullName","Unnamed: 0"])




for i in range(0,len(dl_df.Player)):
    dl_df.Player[i]=dl_df.Player[i].replace(dl_df.Player[i].split(" ").pop(-1),"").strip()

dl_df = dl_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

dl_df = dl_df.drop(columns=["Player","FullName","Unnamed: 0"])


for i in range(0,len(db_df.Player)):
    db_df.Player[i]=db_df.Player[i].replace(db_df.Player[i].split(" ").pop(-1),"").strip()

db_df = db_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

db_df = db_df.drop(columns=["Player","FullName","Unnamed: 0"])




for i in range(0,len(te_df.Player)):
    te_df.Player[i]=te_df.Player[i].replace(te_df.Player[i].split(" ").pop(-1),"").strip()

te_df = te_df.merge(id_df, left_on='Player',right_on="FullName", how = 'inner')

te_df = te_df.drop(columns=["Player","FullName","Unnamed: 0"])
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
qb_df =qb_df.rename(columns={"Unnamed: 19":"Year"})
rb_df = rb_df.rename(columns={"Unnamed: 19":"Year"})
te_df =te_df.rename(columns={"Unnamed: 18":"Year"})
wr_df =wr_df.rename(columns={"Unnamed: 18":"Year"})
             
db_df.to_csv("temp/db_df.csv")
dl_df.to_csv("temp/dl_df.csv")
#dst_df.to_csv("temp/dst_df.csv")
lb_df.to_csv("temp/lb_df.csv")
qb_df.to_csv("temp/qb_df.csv")
rb_df.to_csv("temp/rb_df.csv")
te_df.to_csv("temp/te_df.csv")
wr_df.to_csv("temp/wr_df.csv")

# %%
dst_df = pd.read_csv("fantasy/dst.csv")
for i in range(0,len(dst_df.Player)):
    dst_df.Player[i]=dst_df.Player[i].split("(")[1].split(")")[0]

dst_df = dst_df.merge(team_df, left_on='Player',right_on="TM", how = 'inner')

dst_df = dst_df.drop(columns=["Unnamed: 0","Team","Player"])

dst_df = dst_df.rename(columns={"TM":"TeamID"})
dst_df.to_csv("temp/dst_df.csv")
# Out:
# C:\Users\chand\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
owners_df = pd.read_csv("temp/owners_df.csv")
salary_df = pd.read_csv("temp/salary_df.csv")
stadium_df = pd.read_csv("temp/stadium_df.csv")
team_df = pd.read_csv("temp/team_df.csv")
team_table = pd.read_csv("temp/team_table.csv")
team_statistics = pd.read_csv("temp/team_statistics.csv")

# %%
team_df
# Out:
#      TM                  Team
# 0   ARI     Arizona Cardinals
# 1   ATL       Atlanta Falcons
# 2   BAL      Baltimore Ravens
# 3   BUF         Buffalo Bills
# 4   CAR     Carolina Panthers
# 5   CHI         Chicago Bears
# 6   CIN    Cincinnati Bengals
# 7   CLE      Cleveland Browns
# 8   DAL        Dallas Cowboys
# 9   DEN        Denver Broncos
# 10  DET         Detroit Lions
# 11   GB     Green Bay Packers
# 12  HOU        Houston Texans
# 13  IND    Indianapolis Colts
# 14  JAX  Jacksonville Jaguars
# 15   KC    Kansas City Chiefs
# 16  LAC  Los Angeles Chargers
# 17  LAR      Los Angeles Rams
# 18   LV     Las Vegas Raiders
# 19  MIA        Miami Dolphins
# 20  MIN     Minnesota Vikings
# 21   NE  New England Patriots
# 22   NO    New Orleans Saints
# 23  NYG       New York Giants
# 24  NYJ         New York Jets
# 25  PHI   Philadelphia Eagles
# 26  PIT   Pittsburgh Steelers
# 27  SEA      Seattle Seahawks
# 28   SF   San Francisco 49ers
# 29   TB  Tampa Bay Buccaneers
# ...

# %%
team_df.head()
# Out:
#     TM               Team
# 0  ARI  Arizona Cardinals
# 1  ATL    Atlanta Falcons
# 2  BAL   Baltimore Ravens
# 3  BUF      Buffalo Bills
# 4  CAR  Carolina Panthers

# %%
players_df.to_csv("temp/players_df.csv")

# %%
team_abv_list = []
for i in range(0,len(players_df.team)):
    x = True
    for j in range(0,len(team_df.Team)):
        
        if players_df.team[i] in team_df.Team[j] and x == True:
                   
            team_abv_list.append(team_df.TM[j])
            x=False
                   
            
            
team_abv_list
# Out:
# ['BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'BUF',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'MIA',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
#  'NE',
# ...

# %%
team_statistics = team_statistics.merge(team_df, left_on='team', right_on='Team', how='left')

team_statistics
# Out:
#      Unnamed: 0_x                  team  year  points_scored_gm  rush_yds_gm  \
# 0               0        Dallas Cowboys  2019              27.1        134.6
# 1               1      Baltimore Ravens  2019              33.2        206.0
# 2               2  Tampa Bay Buccaneers  2019              28.6         95.1
# 3               3   San Francisco 49ers  2019              29.9        144.1
# 4               4       Atlanta Falcons  2019              23.8         85.1
# ..            ...                   ...   ...               ...          ...
# 633            26         Detroit Lions  2000              19.2        109.2
# 634            27    San Diego Chargers  2000              16.8         66.4
# 635            28    Cincinnati Bengals  2000              11.6        144.6
# 636            29       Atlanta Falcons  2000              15.8         75.9
# 637            30      Cleveland Browns  2000              10.1         67.8
#
# ...

# %%
team_statistics = team_statistics.drop(columns=['team','Team','Unnamed: 0_x','Unnamed: 0_y'])
team_statistics.rename(columns={'TM':'TeamID'})
# Out:
#      year  points_scored_gm  rush_yds_gm  pass_yds_gm  total_yds_gm  \
# 0    2019              27.1        134.6        296.9         431.5
# 1    2019              33.2        206.0        201.6         407.6
# 2    2019              28.6         95.1        302.8         397.9
# 3    2019              29.9        144.1        237.0         381.1
# 4    2019              23.8         85.1        294.6         379.7
# ..    ...               ...          ...          ...           ...
# 633  2000              19.2        109.2        167.2         276.4
# 634  2000              16.8         66.4        202.4         268.8
# 635  2000              11.6        144.6        121.6         266.2
# 636  2000              15.8         75.9        173.8         249.6
# 637  2000              10.1         67.8        152.8         220.6
#
#      points_allowed_gm  rush_yds_allowed_gm  pass_yds_allowed_gm  \
# 0                 20.1                103.5                223.5
# ...

# %%
team_statistics = team_statistics.rename(columns={'TM':'TeamID'})

team_statistics.to_csv('temp/team_statistics.csv')

# %%
team_statistics
# Out:
#      year  points_scored_gm  rush_yds_gm  pass_yds_gm  total_yds_gm  \
# 0    2019              27.1        134.6        296.9         431.5
# 1    2019              33.2        206.0        201.6         407.6
# 2    2019              28.6         95.1        302.8         397.9
# 3    2019              29.9        144.1        237.0         381.1
# 4    2019              23.8         85.1        294.6         379.7
# ..    ...               ...          ...          ...           ...
# 633  2000              19.2        109.2        167.2         276.4
# 634  2000              16.8         66.4        202.4         268.8
# 635  2000              11.6        144.6        121.6         266.2
# 636  2000              15.8         75.9        173.8         249.6
# 637  2000              10.1         67.8        152.8         220.6
#
#      points_allowed_gm  rush_yds_allowed_gm  pass_yds_allowed_gm  \
# 0                 20.1                103.5                223.5
# ...

# %%
salary_df = pd.read_csv('temp/salary_df.csv')
players_df = pd.read_csv('temp/players_df.csv')

# %%
players_df.head(1)
# Out:
#    Unnamed: 0         PlayerID POS Age     HT       WT Exp College  \
# 0           0  Mario Addison97  DE  32  6' 3"  260 lbs  10    Troy
#
#         FullName First Name Last Name TeamID
# 0  Mario Addison      Mario   Addison    BUF

# %%
salary_df.head(1)
# Out:
#    Unnamed: 0  Rank First_Name Last_Name Pos   TM    Salary
# 0           0   1.0       Kirk   Cousins  QB  MIN  27500000

# %%
salary_df = salary_df.merge(players_df, how = 'left', left_on = ['First_Name','Last_Name'], right_on = ['First Name','Last Name'])

# %%
salary_df = salary_df[['PlayerID','Rank', 'Pos', 'Salary']]
salary_df
# Out:
#                   PlayerID    Rank Pos    Salary
# 0            Kirk Cousins8     1.0  QB  27500000
# 1          Marcus Mariota8     2.0  QB  20922000
# 2           Jameis Winston     2.0  QB  20922000
# 3              Derek Carr4     4.0  QB  19900000
# 4                      NaN     5.0  QB  18500000
# ...                    ...     ...  ..       ...
# 1931       Michael Dogbe91  1584.0  DL    495000
# 1932  Ross Pierschbacher64  1584.0  OL    495000
# 1933        Alex Redmond62  1912.0   G    493236
# 1934         Holton Hill24  1913.0  CB    435882
# 1935                   NaN  1914.0  TE    378000
#
# [1936 rows x 4 columns]

# %%
salary_df = salary_df[salary_df.PlayerID != 'NaN']
salary_df = salary_df.dropna().reset_index(drop=True)

# %%
salary_df.to_csv("../Resources/salary_df.csv")
